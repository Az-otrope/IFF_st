# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import time, date, datetime
import openpyxl
from openpyxl import Workbook

#from sklearn.linear_model import LinearRegression
#import statsmodels.api as sm

import warnings

# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Instruction
# 1. Jump to "Data Wrangling" function

# %% [markdown]
# ## A. Data Cleaning

# %% [markdown]
# **Raw CFU** file is a template. To write a function:
# - skiprows=2
# - key: 'Batch' col
# - features: [Sample description],'Storage form','Temperature (C)','T0','Date','CFU/mL','CFU/g','CV' (?),'Water Acitivty' cols
# - remove rows with NaN in 'Batch' col
# - Change 'Batch' col to 'FD Run ID'
#
# - Change to datetime for "Date, T0"
# - Change to float/number for "CFU/mL, CFU/g, CV": fix DIV/0 to NaN

# %%
# Import the dataset
rawcfu_df = pd.read_csv(filepath_or_buffer="/Users/miu/IFF_st/data/raw/OnSeed_CFU_Test.csv")
rawcfu_df.head()
# Out:
#   Sparkle PIVOT Sample CFU plating data recording sheet. Manually enter your data in columns marked with a ⭐ (optional: †) and the other columns should auto-calculate appropriately. The data are sortable, and can be filtered using the dropdowns in each column.  \
# 0                                                  ⭐
# 1                                              Batch
# 2                                   FDL-105C-T14-Try
# 3                                   FDL-105C-T15-Try
# 4                                   FDL-105D-T20-Try
#
#            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                   ⭐        NaN          †          ⭐          †          ⭐
# 1  Sample Description   Code No.       Logs   No. Reps      Extra      grams
# 2        Seed A, B, C          H       5, 6          3        NaN        0.3
# 3        Seed A, B, C          H       5, 6          3        NaN        0.3
# 4        Seed A, B, C          H       6, 7          3        NaN        0.3
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0        NaN          ⭐        NaN  ...           ⭐           ⭐           †
# 1         mL        Who         T0  ...          R1          R2          R3
# 2        5.7         EC     1/5/23  ...         117         146          89
# 3        5.7         EC     1/5/23  ...         253         147         186
# 4        5.7         EC     1/5/23  ...          73          92          64
#
#   Unnamed: 15 Unnamed: 16      Unnamed: 17         Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN              NaN                 NaN         NaN
# 1      CFU/mL   SD CFU/mL  Extender CFU/mL  SD Extender CFU/mL          CV
# 2    4.69E+04    1.14E+04              NaN                 NaN      24.30%
# 3    7.81E+03    2.14E+03              NaN                 NaN      27.40%
# 4    3.05E+04    5.72E+03              NaN                 NaN      18.70%
#
#       Unnamed: 20 Unnamed: 21
# 0             NaN           ⭐
# 1  Water Activity      Remark
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN        Redo
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Data Wrangling Function

# %%
def data_cleaning(df):
    df.columns = df.iloc[1]
    df = df.iloc[2:].reset_index()
    df.dropna(subset=['Batch'], inplace=True)
    df.drop(df[df['Remark'] == 'Redo'].index, inplace=True)
    df = df[
        ['Batch', 'Sample Description', 'Code No.', 'T0', 'Date', 'CFU/mL', 'SD CFU/mL',
         'Extender CFU/mL', 'SD Extender CFU/mL', 'CV']
    ]
    for idx, row in df.iterrows():
        try:
            df.loc[idx, "CV"] = float(row['CV'].split("%")[0])
        except Exception as e:
            pass

    for col in ['CFU/mL', 'SD CFU/mL', 'Extender CFU/mL', 'SD Extender CFU/mL', 'CV']:
        df[col] = df[col].replace('#DIV/0!', np.NaN)
        df[col] = df[col].astype(float)

    df = df.rename(columns={'Batch': 'FD Run ID', 'CV': 'CV (%)'})

    return df

# %%
def remove_spaces(df):
    """
    This function removes the spaces before and after a string. 
    The function will pass columns with timestamp and numerical datatypes
    """
    for col in df:
        if df[col].dtype == np.dtype('object'):
        
            df[col] = df[col].apply(lambda x:x.strip() if type(x) == "str" else x)
    return df

# %%
def time_feature_eng(df):
    """
    The feature_eng function creates 2 new timedelta features in days and weeks.
    """

    df[['T0', 'Date']] = df[['T0', 'Date']].apply(pd.to_datetime, format="%m/%d/%y")
    df['Day'] = (df['Date'] - df['T0']).apply(lambda x: x.days)

    def num_weeks(row):
        year1, week1, day1 = row['T0'].isocalendar()
        year2, week2, day2 = row['Date'].isocalendar()
        return (year2 - year1) * 52 + (week2 - week1)

    df['Week'] = df.apply(num_weeks, axis=1)

    return df

# %%
def pivot_on_seed(df):
    df = data_cleaning(df)
    df = time_feature_eng(df) # long format

    # select features from input file
    raw_cfu = df.drop(['Sample Description'], axis=1)

    return raw_cfu

# %%
# Import the dataset
data = pd.read_csv(filepath_or_buffer="/Users/miu/IFF_st/data/raw/OnSeed_CFU_Test.csv")

# %%
raw = pivot_on_seed(data)

# %%
clean.to_csv('clean_inpack.csv',index=False)

# %%
raw.head()
# Out:
# 1         FD Run ID Code No.         T0       Date   CFU/mL  SD CFU/mL  \
# 0  FDL-105C-T14-Try        H 2023-01-05 2023-04-26  46900.0    11400.0
# 1  FDL-105C-T15-Try        H 2023-01-05 2023-04-26   7810.0     2140.0
# 3  FDL-105G-T33-Try        H 2023-01-05 2023-04-26    907.0       61.1
# 4  ABKLUB021923AA-1        H 2023-01-05 2023-04-26  29200.0     6660.0
# 5  ABKLUB021923AA-2        H 2023-01-05 2023-04-26  21700.0     6820.0
#
# 1  Extender CFU/mL  SD Extender CFU/mL  CV (%)  Day  Week
# 0              NaN                 NaN    24.3  111    16
# 1              NaN                 NaN    27.4  111    16
# 3              NaN                 NaN     6.7  111    16
# 4              NaN                 NaN    22.8  111    16
# 5              NaN                 NaN    31.4  111    16

# %%
raw.shape
# Out:
# (35, 11)

# %% [markdown]
# ## C. Decay Rate Analysis

# %% [markdown]
# Decay rate calculation uses LINEST function.<br>
# The two variables are time_day (x) and log10_CFU (y).
#
# Use `raw` df to [transform] calculate the decay rate and fit the data

# %% [markdown]
# ---

# %% [markdown]
# **Unit Test**
#
# Use the historical dataset of On-Seed to reproduce the decay data analysis

# %%
onseed_hist = pd.read_csv(filepath_or_buffer="/Users/miu/IFF_st/data/processed/OnSeed_final.csv")

# %%
onseed_hist.head()
# Out:
#    id Unique ID   FD sample ID FD Run ID                Strain Cryo mix  \
# 0   1         A  IFF09152022-2  FDL-099D  Klebsiella variicola      PVT
# 1   1         A  IFF09152022-2  FDL-099D  Klebsiella variicola      PVT
# 2   1         A  IFF09152022-2  FDL-099D  Klebsiella variicola      PVT
# 3   1         A  IFF09152022-2  FDL-099D  Klebsiella variicola      PVT
# 4   1         A  IFF09152022-2  FDL-099D  Klebsiella variicola      PVT
#
#    FD_recipe Desiccant                          FC Aged  ... Plating Date  \
# 0  PVT090-A0    5%SIO2  Greens, high EPS, CR broth   no  ...      12/6/22
# 1  PVT090-A0    5%SIO2  Greens, high EPS, CR broth   no  ...     12/13/22
# 2  PVT090-A0    5%SIO2  Greens, high EPS, CR broth   no  ...     12/20/22
# 3  PVT090-A0    5%SIO2  Greens, high EPS, CR broth   no  ...          NaN
# 4  PVT090-A0    5%SIO2  Greens, high EPS, CR broth   no  ...       1/3/23
#
#     CFU/Seed  CFU/Seed Stdev  T0?  Days Log CFU Y-Intercept  Decay Rate  \
# 0  3800000.0        280000.0  Yes   0.0    6.58         NaN         NaN
# 1  1670000.0        266000.0   No   7.0    6.22        6.58      -0.051
# 2   793000.0        156000.0   No  14.0    5.90        6.57      -0.049
# 3        NaN             NaN   No   NaN     NaN         NaN         NaN
# 4    25700.0          7110.0   No  28.0    4.41        6.73      -0.077
#
#    EstDays  T0 Date
# 0      NaN  12/6/22
# 1    50.45  12/6/22
# 2    52.97  12/6/22
# 3      NaN  12/6/22
# 4    35.02  12/6/22
#
# [5 rows x 26 columns]

# %%
onseed_hist.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['id', 'Unique ID', 'FD sample ID', 'FD Run ID', 'Strain', 'Cryo mix',
#        'FD_recipe', 'Desiccant', 'FC', 'Aged', 'Unnamed: 10', 'DR_latest',
#        'Est_latest', 'ExtenderCFU_ml', 'ExtenderCFU_ml_SD',
#        'Application Log Loss', 'Plating Date', 'CFU/Seed', 'CFU/Seed Stdev',
#        'T0?', 'Days', 'Log CFU', 'Y-Intercept', 'Decay Rate', 'EstDays',
#        'T0 Date'],
#       dtype='object')>

# %%
onseed_hist.dropna(subset=['FD sample ID'], inplace=True)

# %%
onseed_hist.shape
# Out:
# (981, 26)

# %% [markdown]
# Select **sample_info df**
#
# The information is from In-pack becasue the On-seed samples are derived from there

# %%
info_df = onseed_hist[['FD Run ID', 'FD sample ID', 'Strain', 'Cryo mix', 'FD_recipe', 'Desiccant', 'FC']]

# %%
info_df = info_df.rename(columns={"FC": "Ferm condition"})

# %%
info_df.head()
# Out:
#   FD Run ID   FD sample ID                Strain Cryo mix  FD_recipe  \
# 0  FDL-099D  IFF09152022-2  Klebsiella variicola      PVT  PVT090-A0
# 1  FDL-099D  IFF09152022-2  Klebsiella variicola      PVT  PVT090-A0
# 2  FDL-099D  IFF09152022-2  Klebsiella variicola      PVT  PVT090-A0
# 3  FDL-099D  IFF09152022-2  Klebsiella variicola      PVT  PVT090-A0
# 4  FDL-099D  IFF09152022-2  Klebsiella variicola      PVT  PVT090-A0
#
#   Desiccant              Ferm condition
# 0    5%SIO2  Greens, high EPS, CR broth
# 1    5%SIO2  Greens, high EPS, CR broth
# 2    5%SIO2  Greens, high EPS, CR broth
# 3    5%SIO2  Greens, high EPS, CR broth
# 4    5%SIO2  Greens, high EPS, CR broth

# %% [markdown]
# *TO-DO* on the web app
# 1. Select the sub df above from the In-pack final compilation for joining with On-seed CFU and On-seed real_input

# %% [markdown]
# Select **user inputs**

# %%
os_real_input = onseed_hist[['FD sample ID', 'FD Run ID', 'Aged', 'Unnamed: 10', 
                             'T0 Date', 'Plating Date', 'T0?']]
os_real_input.head()
# Out:
#     FD sample ID FD Run ID Aged Unnamed: 10  T0 Date Plating Date  T0?
# 0  IFF09152022-2  FDL-099D   no       Fresh  12/6/22      12/6/22  Yes
# 1  IFF09152022-2  FDL-099D   no       Fresh  12/6/22     12/13/22   No
# 2  IFF09152022-2  FDL-099D   no       Fresh  12/6/22     12/20/22   No
# 3  IFF09152022-2  FDL-099D   no       Fresh  12/6/22          NaN   No
# 4  IFF09152022-2  FDL-099D   no       Fresh  12/6/22       1/3/23   No

# %%
os_real_input = os_real_input.rename(columns={"Unnamed: 10": "Sample condition", "T0?": "Is T0?"})

# %%
os_real_input.head()
# Out:
#     FD sample ID FD Run ID Aged Sample condition  T0 Date Plating Date Is T0?
# 0  IFF09152022-2  FDL-099D   no            Fresh  12/6/22      12/6/22    Yes
# 1  IFF09152022-2  FDL-099D   no            Fresh  12/6/22     12/13/22     No
# 2  IFF09152022-2  FDL-099D   no            Fresh  12/6/22     12/20/22     No
# 3  IFF09152022-2  FDL-099D   no            Fresh  12/6/22          NaN     No
# 4  IFF09152022-2  FDL-099D   no            Fresh  12/6/22       1/3/23     No

# %%
sns.heatmap(os_real_input.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Select **cfu_df**

# %%
os_cfu_df = onseed_hist[['FD Run ID','ExtenderCFU_ml', 'ExtenderCFU_ml_SD',
                         'W0', 'W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7','W8',
                         'SD0', 'SD1', 'SD2', 'SD3', 'SD4', 'SD5', 'SD6', 'SD7', 'SD8']]

# %%
os_cfu_df.head()
# Out:
#       FD Run ID  ExtenderCFU_ml  ExtenderCFU_ml_SD         W0         W1  \
# 0      FDL-099D    2.350000e+10       2.840000e+09  3800000.0  1670000.0
# 1     FDL-101A1    6.680000e+09       4.850000e+08   308000.0   184000.0
# 2  FDL-105A-T02    1.480000e+10       7.810000e+08  1240000.0        NaN
# 3  FDL-105A-T03    2.600000e+09       1.840000e+08   137000.0        NaN
# 4  FDL-105A-T04    1.170000e+10       6.240000e+08  1150000.0        NaN
#
#          W2        W3        W4        W5  W6  ...        W8       SD0  \
# 0  793000.0       NaN   25700.0  404000.0 NaN  ...  177000.0  2.80E+05
# 1  105000.0       NaN    3730.0   43600.0 NaN  ...    4310.0  5.56E+04
# 2  403000.0  243000.0  144000.0       NaN NaN  ...    9080.0  3.56E+05
# 3   12000.0    9390.0    4360.0       NaN NaN  ...     280.0  1.51E+04
# 4  272000.0  131000.0   64100.0       NaN NaN  ...   11900.0  1.40E+05
#
#         SD1       SD2      SD3      SD4      SD5  SD6  SD7  SD8
# 0  266000.0  156000.0      NaN   7110.0  31300.0  NaN  NaN  NaN
# 1   38200.0   21200.0      NaN   2200.0   4420.0  NaN  NaN  NaN
# 2       NaN   16200.0  50600.0  24200.0      NaN  NaN  NaN  NaN
# 3       NaN    3490.0   1460.0    902.0      NaN  NaN  NaN  NaN
# 4       NaN   65800.0  20100.0  16000.0      NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
os_cfu_df['Application_loss_CFU'] = np.log10(os_cfu_df['ExtenderCFU_ml']*0.000887) - np.log10(os_cfu_df['W0'])

# %%
os_cfu_df.head()
# Out:
#       FD Run ID  ExtenderCFU_ml  ExtenderCFU_ml_SD         W0         W1  \
# 0      FDL-099D    2.350000e+10       2.840000e+09  3800000.0  1670000.0
# 1     FDL-101A1    6.680000e+09       4.850000e+08   308000.0   184000.0
# 2  FDL-105A-T02    1.480000e+10       7.810000e+08  1240000.0        NaN
# 3  FDL-105A-T03    2.600000e+09       1.840000e+08   137000.0        NaN
# 4  FDL-105A-T04    1.170000e+10       6.240000e+08  1150000.0        NaN
#
#          W2        W3        W4        W5  W6  ...       SD0       SD1  \
# 0  793000.0       NaN   25700.0  404000.0 NaN  ...  2.80E+05  266000.0
# 1  105000.0       NaN    3730.0   43600.0 NaN  ...  5.56E+04   38200.0
# 2  403000.0  243000.0  144000.0       NaN NaN  ...  3.56E+05       NaN
# 3   12000.0    9390.0    4360.0       NaN NaN  ...  1.51E+04       NaN
# 4  272000.0  131000.0   64100.0       NaN NaN  ...  1.40E+05       NaN
#
#         SD2      SD3      SD4      SD5  SD6  SD7  SD8  Application_loss_CFU
# 0  156000.0      NaN   7110.0  31300.0  NaN  NaN  NaN              0.739208
# 1   21200.0      NaN   2200.0   4420.0  NaN  NaN  NaN              1.284149
# 2   16200.0  50600.0  24200.0      NaN  NaN  NaN  NaN              1.024764
# 3    3490.0   1460.0    902.0      NaN  NaN  NaN  NaN              1.226176
# 4   65800.0  20100.0  16000.0      NaN  NaN  NaN  NaN              0.955412
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Decay Rate Calculation Function

# %%
# TO-DO: instanstiate the const col first
# sm.add_const(X)

# %%
def decay_rate(df):
    """
    The decay_rate function calculates the rate at which the material's concentration (in Log10_CFU) decay over time.
    The function takes in time (day) as the independent variable (X) and Log10(CFU) as the dependent variable (y).
    A linear regression model is instantiated to calculate the slope, r-squared, and the 95% confidence interval (CI) of the slope.
    The model will skip entries having fewer than 2 datapoints due to avoid overfitting and bias. 
    
    INPUT: a dataframe containing raw plating CFU data (wide format)
        - X (independent variable): time (day) as int or float
        - y (dependent variable): Log10(CFU) as float
        
    OUTPUT: a dataframe containing the samples information, their CFU values at each timepoint, the decay rate over time,
        the R-squared of the linear fit equation, the lower and upper values of the 95% confidence interval of the decay rate.
        - decay_rate: slope of the linear fit equation (m)
        - r-squared: coefficient of determination
        - ci_slope: [lower,upper] values of the slope's 95% CI
    """
    
    df['LogCFU'] = np.log10(df['CFU/g'])
    
    # No calculation if there are only 1 or 2 observant (day-LogCFU)
    if len(df) < 3: 
        decay_df = pd.Series({'Decay Rate': None, 'R-squared': None,
                             'CI95_lower': None,'CI95_upper': None})
        return decay_df
        
    # Extract the input feature and target variable
    X = df[['Day', "const"]] #require to be float/int
    y = df['LogCFU']
    
    # Fit the linear regression model
    model = sm.OLS(y, X)
    results = model.fit()
    
    # Extract the coefficient and R-squared
    decay_rate = results.params[1]
    r_squared = results.rsquared
    
    # Extract the 95% confidence interval
    ci = results.conf_int(alpha=0.05)
    ci_slope = ci.loc['Day']
    
    decay_df = pd.Series({'Decay Rate': decay_rate, 'R-squared': r_squared,
                         'CI95_lower':ci_slope[0], 'CI95_upper':ci_slope[1]})
    
    return decay_df

# %% [markdown]
# Unit test 1

# %%
t2 = raw.copy()

# %%
t2.head()
# Out:
# 1         FD Run ID Sample Description Storage form Temperature-Celsius  \
# 0  IFF09152022-2 T1                NaN          NaN                  21
# 1  IFF09152022-2 T2                NaN          NaN                  21
# 3  IFF09152022-2 T3                NaN          NaN                   4
# 4  IFF09152022-2 T4                NaN          NaN                  21
# 5  IFF09152022-3 T1                NaN          NaN                  21
#
# 1         T0       Date        CFU/mL         CFU/g CV (%)  Water Activity  \
# 0 2023-01-05 2023-02-27  7.410000e+08  1.410000e+10    8.6           0.254
# 1 2023-01-05 2023-02-27  1.970000e+09  3.750000e+10   10.0           0.198
# 3 2023-01-05 2023-03-01  2.300000e+01  4.500000e+00    8.6             NaN
# 4 2023-01-05 2023-02-27  4.550000e+08  8.640000e+09    7.9           0.267
# 5 2023-01-05 2023-02-27  2.440000e+08  4.640000e+09    4.3           0.227
#
# 1  Day  Week
# 0   53     8
# 1   53     8
# 3   55     8
# 4   53     8
# 5   53     8

# %%
t2.shape
# Out:
# (65, 12)

# %%
t2 = sm.add_constant(t2)

# %%
decay_t2 = t2.groupby('FD Run ID').apply(decay_rate).reset_index()

# %%
decay_t2
# Out:
#               FD Run ID Decay Rate R-squared CI95_lower CI95_upper
# 0       ABKLUB 030823AA       None      None       None       None
# 1       ABKLUB 031023AA       None      None       None       None
# 2       ABKLUB 031323AA       None      None       None       None
# 3    ABKLUB 031623AA #9       None      None       None       None
# 4   ABKLUB 031823AA #10       None      None       None       None
# ..                  ...        ...       ...        ...        ...
# 56     IFF10202022-1 T4       None      None       None       None
# 57     IFF10202022-2 T1       None      None       None       None
# 58     IFF10202022-2 T2       None      None       None       None
# 59     IFF10202022-2 T3       None      None       None       None
# 60     IFF10202022-2 T4       None      None       None       None
#
# [61 rows x 5 columns]

# %%
decay_t2[decay_t2['Decay Rate'].notnull()]
# Out:
# Empty DataFrame
# Columns: [FD Run ID, Decay Rate, R-squared, CI95_lower, CI95_upper]
# Index: []

# %%
decay_t2_final = pd.merge(left=clean,right=decay_t2,on='FD Run ID')

# %%
decay_t2_final
# Out:
#              FD Run ID         T0       Date     W0_CFU/mL  W1_CFU/mL  \
# 0     IFF09152022-2 T1 2023-01-05 2023-02-27           NaN        NaN
# 1     IFF09152022-2 T2 2023-01-05 2023-02-27           NaN        NaN
# 2     IFF09152022-2 T3 2023-01-05 2023-03-01           NaN        NaN
# 3     IFF09152022-2 T4 2023-01-05 2023-02-27           NaN        NaN
# 4     IFF09152022-3 T1 2023-01-05 2023-02-27           NaN        NaN
# ..                 ...        ...        ...           ...        ...
# 56        FDL-105K-T42 2023-04-07 2023-04-07  4.030000e+08        NaN
# 57        FDL-105K-T44 2023-04-07 2023-04-07  1.130000e+08        NaN
# 58  FDL-105EF-T24 TMC1 2023-04-07 2023-04-07  1.570000e+09        NaN
# 59  FDL-105EF-T24 TMC2 2023-04-07 2023-04-07  2.120000e+09        NaN
# 60       FD-23-0006-T3 2023-03-13 2023-03-15  1.720000e+09        NaN
#
#        W8_CFU/mL      W0_CFU/g  W1_CFU/g      W8_CFU/g  W0_Water Activity  \
# 0   7.410000e+08           NaN       NaN  1.410000e+10                NaN
# 1   1.970000e+09           NaN       NaN  3.750000e+10                NaN
# 2   2.300000e+01           NaN       NaN  4.500000e+00                NaN
# 3   4.550000e+08           NaN       NaN  8.640000e+09                NaN
# 4   2.440000e+08           NaN       NaN  4.640000e+09                NaN
# ..           ...           ...       ...           ...                ...
# 56           NaN  7.650000e+09       NaN           NaN                NaN
# 57           NaN  2.150000e+09       NaN           NaN                NaN
# 58           NaN  2.990000e+10       NaN           NaN              0.298
# 59           NaN  4.030000e+10       NaN           NaN              0.301
# 60           NaN  3.770000e+11       NaN           NaN                NaN
#
#     W1_Water Activity  W8_Water Activity Decay Rate R-squared CI95_lower  \
# 0                 NaN              0.254       None      None       None
# 1                 NaN              0.198       None      None       None
# 2                 NaN                NaN       None      None       None
# 3                 NaN              0.267       None      None       None
# 4                 NaN              0.227       None      None       None
# ..                ...                ...        ...       ...        ...
# 56                NaN                NaN       None      None       None
# 57                NaN                NaN       None      None       None
# 58                NaN                NaN       None      None       None
# 59                NaN                NaN       None      None       None
# 60                NaN                NaN       None      None       None
#
#    CI95_upper
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# ..        ...
# 56       None
# 57       None
# 58       None
# 59       None
# 60       None
#
# [61 rows x 16 columns]

# %%
clean.shape, decay_t2.shape
# Out:
# ((61, 12), (61, 5))

# %%
decay_t2_final[decay_t2_final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [FD Run ID, T0, Date, W0_CFU/mL, W1_CFU/mL, W8_CFU/mL, W0_CFU/g, W1_CFU/g, W8_CFU/g, W0_Water Activity, W1_Water Activity, W8_Water Activity, Decay Rate, R-squared, CI95_lower, CI95_upper]
# Index: []

# %% [markdown]
# **Insights**: this example is a test case for the web app. The raw and clean dfs is from the CFU plating .csv file
#
# *To-do* in the web app:
# 1. Add 'const' col before call the decay_rate func
# 2. Join the 'clean' df with the 'decay_df'
# 3. Drop duplicates

# %% [markdown]
# Unit test 2

# %%
unpivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 223
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FD Run ID  118 non-null    object
#  1   Day        118 non-null    object
#  2   CFU/g      118 non-null    float64
#  3   LogCFU     118 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 4.6+ KB

# %%
t3 = unpivot_df.copy()

# %%
to_unpivot[to_unpivot.duplicated()]
# Out:
#                  FD Run ID             0  14  28  56  84
# 174         FDL-111EF-T18   8.740000e+10 NaN NaN NaN NaN
# 175  FDL-111EF-T18-CC1TMC1  1.009111e+11 NaN NaN NaN NaN
# 176     FDL-111EF-T18-TMC1  8.444444e+10 NaN NaN NaN NaN
# 177          FDL-111EF-T19  1.089333e+11 NaN NaN NaN NaN
# 178  FDL-111EF-T19-CC1TMC1  1.427111e+11 NaN NaN NaN NaN
# 179     FDL-111EF-T19-TMC1  1.072444e+11 NaN NaN NaN NaN
# 180           FDL-111G-T22  7.304444e+10 NaN NaN NaN NaN
# 181   FDL-111G-T22-CC1TMC1  7.600000e+10 NaN NaN NaN NaN
# 182      FDL-111G-T22-TMC1  6.417778e+10 NaN NaN NaN NaN
# 183          FDL-111G-T23   7.388889e+10 NaN NaN NaN NaN
# 184   FDL-111G-T23-CC1TMC1  7.811111e+10 NaN NaN NaN NaN

# %%
t3['Day'] = t3['Day'].astype(float)

# %%
t3 = sm.add_constant(t3)

# %%
decay_t3 = t3.groupby('FD Run ID').apply(decay_rate).reset_index()

# %%
decay_t3.head()
# Out:
#           FD Run ID  Decay Rate  R-squared  CI95_lower  CI95_upper
# 0  FDL-105B-T10-CC1   11.101897   0.999318   -0.008902   -0.004465
# 1  FDL-105B-T10-CC2   11.171626   0.837602   -0.043805    0.030520
# 2  FDL-105B-T10-SKP         NaN        NaN         NaN         NaN
# 3  FDL-105B-T10-Try         NaN        NaN         NaN         NaN
# 4  FDL-105C-T14-Try   11.040415   0.848867   -0.037421    0.025656

# %%
decay_t3_final = pd.merge(left=to_unpivot,right=decay_t3,on='FD Run ID')

# %%
decay_t3_final.head()
# Out:
#             FD Run ID             0            14            28  56  84  \
# 0   FDL-105EF-T24-CC1  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1   FDL-105EF-T24-CC2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2   FDL-105EF-T24-SO1  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3   FDL-105EF-T24-SO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4  FDL-105EF-T24-TMC1  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper
# 0   11.095780   0.884324   -0.079040    0.050789
# 1   11.119291   0.943177   -0.066643    0.034282
# 2   11.078498   0.965821   -0.053539    0.021955
# 3   11.089304   0.999838   -0.023865   -0.017218
# 4   11.151777   0.746866   -0.173616    0.132266

# %%
decay_t3_final[decay_t3_final.duplicated()]
# Out:
#                 FD Run ID             0  14  28  56  84  Decay Rate  \
# 24         FDL-111EF-T18   8.740000e+10 NaN NaN NaN NaN         NaN
# 26  FDL-111EF-T18-CC1TMC1  1.009111e+11 NaN NaN NaN NaN         NaN
# 28     FDL-111EF-T18-TMC1  8.444444e+10 NaN NaN NaN NaN         NaN
# 30          FDL-111EF-T19  1.089333e+11 NaN NaN NaN NaN         NaN
# 32  FDL-111EF-T19-CC1TMC1  1.427111e+11 NaN NaN NaN NaN         NaN
# 34     FDL-111EF-T19-TMC1  1.072444e+11 NaN NaN NaN NaN         NaN
# 36           FDL-111G-T22  7.304444e+10 NaN NaN NaN NaN         NaN
# 38   FDL-111G-T22-CC1TMC1  7.600000e+10 NaN NaN NaN NaN         NaN
# 40      FDL-111G-T22-TMC1  6.417778e+10 NaN NaN NaN NaN         NaN
# 42          FDL-111G-T23   7.388889e+10 NaN NaN NaN NaN         NaN
# 44   FDL-111G-T23-CC1TMC1  7.811111e+10 NaN NaN NaN NaN         NaN
#
#     R-squared  CI95_lower  CI95_upper
# 24        NaN         NaN         NaN
# 26        NaN         NaN         NaN
# 28        NaN         NaN         NaN
# 30        NaN         NaN         NaN
# 32        NaN         NaN         NaN
# 34        NaN         NaN         NaN
# 36        NaN         NaN         NaN
# 38        NaN         NaN         NaN
# 40        NaN         NaN         NaN
# 42        NaN         NaN         NaN
# 44        NaN         NaN         NaN

# %%
decay_t3_final.drop_duplicates(inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## D. 95% CI Graph

# %%
a
# Out:
#             FD Run ID   Day         CFU/g     LogCFU
# 6    FDL-105B-T10-CC1   0.0  1.260333e+11  11.100485
# 73   FDL-105B-T10-CC1  14.0  1.026000e+11  11.011147
# 140  FDL-105B-T10-CC1  28.0  8.191111e+10  10.913343

# %%
# provide 95%CI grpah
sns.lmplot(x='Day', y='LogCFU', data=a, fit_reg=True, ci=95)
#sns.lmplot(x='Day', y='LogCFU', data=a, fit_reg=True, ci=95, n_boot=1000)

# %% [markdown]
# ---

# %% [markdown]
# # Joining with In-pack Analysis

# %% [markdown]
# ## A. Structure of final In-pack report TO ACHIEVE

# %%
inpack_df = pd.read_excel("/Users/miu/IFF_st/Data files/PIVOT Sample Master List 2023_10May23.xlsm", sheet_name='WP4 In-pack Data')
inpack_df.head()
# Out:
#    Unique ID   FD sample ID FD Run ID                Strain Cryo mix  \
# 0        1.0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 1        2.0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 2        3.0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 3        4.0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 4        5.0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
#
#                                     Sub-Sample    Ferm Condition  \
# 0                            pellet_21_mylar_n  Greens, high EPS
# 1                        pellet_21_mylar_cacl2  Greens, high EPS
# 2                   unbulked powder_21_mylar_n  Greens, high EPS
# 3  bulked powder, pre-dried bulking_21_mylar_n  Greens, high EPS
# 4           bulked powder, w/o sio2_21_mylar_n  Greens, high EPS
#
#                        Storage form  Temperature (°C) Container  ...  \
# 0                            Pellet                21     Mylar  ...
# 1                            Pellet                21     Mylar  ...
# 2                   Unbulked powder                21     Mylar  ...
# 3  Bulked powder, pre-dried bulking                21     Mylar  ...
# 4           Bulked powder, w/o SiO2                21     Mylar  ...
#
#   Rsquared_fitted decay_rate_errbar decay_rate_lower95interval  \
# 0        0.996659          0.000881                  -0.008642
# 1        0.939662          0.005588                  -0.016840
# 2        0.990339          0.002946                  -0.018166
# 3        0.993116          0.001788                  -0.012742
# 4        0.998539          0.001091                  -0.015640
#
#   decay_rate_upper95interval  estimate_day_2e10  Week 0 Aw  Week 2 Aw  \
# 0                  -0.006880         168.374192      0.165        NaN
# 1                  -0.005663         116.142074      0.165        NaN
# 2                  -0.012273          85.502213      0.289        NaN
# 3                  -0.009167          88.342199      0.224        NaN
# 4                  -0.013459          73.940614      0.229        NaN
#
#    Week 4 Aw  Week 8 Aw  Week 12 Aw
# 0      0.175      0.205         NaN
# 1      0.125      0.153         NaN
# 2       0.23      0.268         NaN
# 3      0.174      0.221         NaN
# 4       0.21      0.257         NaN
#
# [5 rows x 30 columns]

# %%
inpack_df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Unique ID', 'FD sample ID', 'FD Run ID', 'Strain', 'Cryo mix',
#        'Sub-Sample', 'Ferm Condition', 'Storage form', 'Temperature (°C)',
#        'Container', 'Bulking', 'Desiccant', 'Quantity (g)', 'Sample location',
#        'Week 0 CFU/g', 'Week 2 CFU/g', 'Week 4 CFU/g', 'Week 8 CFU/g',
#        'Week 12 CFU/g', 'decay_rate_fitted', 'Rsquared_fitted',
#        'decay_rate_errbar', 'decay_rate_lower95interval',
#        'decay_rate_upper95interval', 'estimate_day_2e10', 'Week 0 Aw',
#        'Week 2 Aw', 'Week 4 Aw', 'Week 8 Aw', 'Week 12 Aw'],
#       dtype='object')>

# %%
inpack_df.drop(['Unique ID','Quantity (g)','Sample location','Week 0 Aw',
                'Week 2 Aw', 'Week 4 Aw', 'Week 8 Aw', 'Week 12 Aw'],axis=1,inplace=True)

# %% [markdown]
# *In-pack* available features:
# - Key: FD Run ID
# - CFU values by week
# - Water activity by week
#
# **Features carry** to *In-pack*:
# - Key: **'FD Run ID'**
# - Cols: 'Strain','FD Recipe', 'Cryo mix','Ferm condition','Container',
#
# **User Inputs** for 'In-pack' (create a new form/table, different from the Sample Info table):
# - 'Temperature (°C)', 'Container', 'Bulking', 'Desiccant', 'Storage form'
#
#     Note:
#     - Ferm condition: shorten the description from the "Info"
#
# **Features to calculate**
# - sub-sample: generated from storage form, temp, container, desciccant
# - 'decay_rate_fitted', 'Rsquared_fitted','decay_rate_errbar', 'decay_rate_lower95interval', 'decay_rate_upper95interval', 'estimate_day_2e10'

# %%
inpack_df.head()
# Out:
#     FD sample ID FD Run ID                Strain Cryo mix  \
# 0  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 1  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 2  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 3  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
# 4  IFF09152022-1  FDL-099A  Klebsiella variicola      PVT
#
#                                     Sub-Sample    Ferm Condition  \
# 0                            pellet_21_mylar_n  Greens, high EPS
# 1                        pellet_21_mylar_cacl2  Greens, high EPS
# 2                   unbulked powder_21_mylar_n  Greens, high EPS
# 3  bulked powder, pre-dried bulking_21_mylar_n  Greens, high EPS
# 4           bulked powder, w/o sio2_21_mylar_n  Greens, high EPS
#
#                        Storage form  Temperature (°C) Container Bulking  ...  \
# 0                            Pellet                21     Mylar     PVT  ...
# 1                            Pellet                21     Mylar     PVT  ...
# 2                   Unbulked powder                21     Mylar     PVT  ...
# 3  Bulked powder, pre-dried bulking                21     Mylar     PVT  ...
# 4           Bulked powder, w/o SiO2                21     Mylar     PVT  ...
#
#   Week 2 CFU/g  Week 4 CFU/g  Week 8 CFU/g  Week 12 CFU/g  decay_rate_fitted  \
# 0          NaN  2.584000e+11  1.490000e+11            NaN          -0.007761
# 1          NaN  2.698000e+11  9.500000e+10            NaN          -0.011252
# 2          NaN  1.774600e+11  5.624000e+10            NaN          -0.015220
# 3          NaN  1.014600e+11  4.522000e+10            NaN          -0.010955
# 4          NaN  9.918000e+10  3.648000e+10            NaN          -0.014549
#
#    Rsquared_fitted  decay_rate_errbar  decay_rate_lower95interval  \
# 0         0.996659           0.000881                   -0.008642
# 1         0.939662           0.005588                   -0.016840
# 2         0.990339           0.002946                   -0.018166
# 3         0.993116           0.001788                   -0.012742
# 4         0.998539           0.001091                   -0.015640
#
#    decay_rate_upper95interval  estimate_day_2e10
# 0                   -0.006880         168.374192
# 1                   -0.005663         116.142074
# 2                   -0.012273          85.502213
# 3                   -0.009167          88.342199
# 4                   -0.013459          73.940614
#
# [5 rows x 22 columns]

# %% [markdown]
# ## B. Dataset Preparation

# %% [markdown]
# ### Sample Info

# %%
master_lst = pd.read_csv('sample_info.csv')

# %%
master_lst.head()
# Out:
#   FD sample ID     FD Run ID                Strain    EFT date       Broth ID  \
# 0  22PT1202-10  FDL-105A-T01  Klebsiella variicola  2022-12-01   P080-22-Y048
# 1  22PT1202-12  FDL-105A-T02  Klebsiella variicola  2022-12-01   P080-22-Y048
# 2   22PT1202-5  FDL-105A-T03    Kosakonia sacchari  2022-12-01  P080-22-Y046
# 3  22PT1202-11  FDL-105A-T04  Klebsiella variicola  2022-12-01   P080-22-Y048
# 4   22PT1202-1  FDL-105B-T05    Kosakonia sacchari  2022-12-01  P080-22-Y046
#
#   Fermentation Scale                                     Ferm condition  \
# 0                14L  Potato peptone and tryptone, high viscosity by...
# 1                14L  Potato peptone and tryptone, high viscosity by...
# 2                14L  Potato peptone and tryptone, high viscosity by...
# 3                14L  Potato peptone and tryptone, high viscosity by...
# 4                14L         Potato peptone and tryptone, low viscosity
#
#    EFT (hr)  Broth titer (CFU/mL)  Broth age (day)  ... FD run time (hr)  \
# 0      48.0          3.540000e+11              1.0  ...             57.0
# 1      48.0          3.540000e+11              1.0  ...             57.0
# 2      48.0          1.180000e+11              1.0  ...             57.0
# 3      48.0          3.540000e+11              1.0  ...             57.0
# 4      48.0          1.180000e+11              1.0  ...             57.0
#
#   Primary ramp rate (C/min)      PA receive date  \
# 0                       NaN  2022-12-20 00:00:00
# 1                       NaN  2022-12-20 00:00:00
# 2                       NaN  2022-12-20 00:00:00
# 3                       NaN  2022-12-20 00:00:00
# 4                       NaN  2022-12-22 00:00:00
#
#                            Dried appearance   Container  Water activity  \
# 0                   fused/melted moist cake  Foil pouch            0.37
# 1                         Collapse, no dust  Foil pouch            0.06
# 2                       Collapse, some dust  Foil pouch            0.24
# 3                         Collapse, no dust  Foil pouch            0.05
# 4  friable cake, readily broke into pellets  Foil pouch            0.42
#
#   Viability (CFU/g) Cryo mix Coef Yield (%)  Log Loss
# 0               NaN         0.380       NaN       NaN
# 1      1.840000e+11         0.342     17.78     -0.75
# 2      6.610000e+10         0.285     15.96     -0.80
# 3      3.150000e+11         0.285     25.36     -0.60
# 4      4.070000e+10         0.380     13.11     -0.88
#
# [5 rows x 29 columns]

# %%
master_lst.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['FD sample ID', 'FD Run ID', 'Strain', 'EFT date', 'Broth ID',
#        'Fermentation Scale', 'Ferm condition', 'EFT (hr)',
#        'Broth titer (CFU/mL)', 'Broth age (day)', 'Pelletization date',
#        'Cryo mix', 'Ingredient 1', 'Ingredient 2', 'Ingredient 3',
#        'Cryo mix addition rate', 'FD start date', 'FD cycle recipe',
#        'FD pressure (mTorr)', 'FD run time (hr)', 'Primary ramp rate (C/min)',
#        'PA receive date', 'Dried appearance', 'Container', 'Water activity',
#        'Viability (CFU/g)', 'Cryo mix Coef', 'Yield (%)', 'Log Loss'],
#       dtype='object')>

# %% [markdown]
# **INFO from Master list TO MERGE**

# %% [markdown]
# *To-do* in the web app:
# 1. Map the 'Ferm condition'

# %%
info_df = master_lst[['FD sample ID', 'FD Run ID', 'Strain','Ferm condition','Cryo mix']]

# %%
info_df.head(10)
# Out:
#   FD sample ID     FD Run ID                Strain  \
# 0  22PT1202-10  FDL-105A-T01  Klebsiella variicola
# 1  22PT1202-12  FDL-105A-T02  Klebsiella variicola
# 2   22PT1202-5  FDL-105A-T03    Kosakonia sacchari
# 3  22PT1202-11  FDL-105A-T04  Klebsiella variicola
# 4   22PT1202-1  FDL-105B-T05    Kosakonia sacchari
# 5   22PT1202-3  FDL-105B-T06    Kosakonia sacchari
# 6   22PT1202-4  FDL-105B-T07    Kosakonia sacchari
# 7   22PT1117-7  FDL-105B-T08  Klebsiella variicola
# 8   22PT1202-6  FDL-105B-T09    Kosakonia sacchari
# 9   22PT1117-8  FDL-105B-T10  Klebsiella variicola
#
#                                       Ferm condition Cryo mix
# 0  Potato peptone and tryptone, high viscosity by...      SKP
# 1  Potato peptone and tryptone, high viscosity by...      DSR
# 2  Potato peptone and tryptone, high viscosity by...   PVT70%
# 3  Potato peptone and tryptone, high viscosity by...   PVT70%
# 4         Potato peptone and tryptone, low viscosity      SKP
# 5         Potato peptone and tryptone, low viscosity      DSR
# 6  Potato peptone and tryptone, high viscosity by...      SKP
# 7         Potato peptone and tryptone, low viscosity      SKP
# 8  Potato peptone and tryptone, high viscosity by...      DSR
# 9         Potato peptone and tryptone, low viscosity   PVT70%

# %%
info_df['Ferm condition'].nunique()
# Out:
# 8

# %%
info_df['Ferm condition'] = info_df['Ferm condition'].apply(lambda x:x.strip())

# %%
# TODO: change 'FD cycle recipe' -> 'FD recipe'
info_df.rename(columns={'FD cycle recipe':'FD recipe'}, inplace=True)

# %%
# TODO: mapping dictionary for 'Ferm condition'
# e.g.: {Peptone only}:['P only']

# %%
info_df['Ferm condition'].value_counts()
# Out:
# Tryptone+Peptone                                                                11
# Glucose, no EPS, CR                                                             10
# Glucose                                                                         10
# Peptone only, upconcentrated                                                     7
# Tryptone only                                                                    7
# Peptone only                                                                     6
# Potato peptone and tryptone, low viscosity                                       6
# Potato peptone and tryptone, high viscosity by post-ferm addition of 0.7% XG     6
# tryptone only                                                                    6
# Glucose, high EPS, CR                                                            6
# repeat of P080-22-Y007, tryptone + potato peptone                                3
# Tryptone + potato peptone, lower top feed rate, no EPS                           3
# tryptone + potato peptone, low top feed rate, no EPS, w 0.7% XG                  3
# repeat of P080-22-Y005, tryptone + potato peptone                                3
# Potato peptone only, less EPS, pH control                                        3
# Glucose, no EPS                                                                  3
# Glucose, high EPS, CR broth                                                      3
# Greens                                                                           1
# Name: Ferm condition, dtype: int64

# %%
inpack_df['Ferm Condition'].value_counts()
# Out:
# T only               41
# P only               29
# T+P, no EPS          25
# T+P, 0.7% XG         22
# Glucose, no EPS      19
# T+P, high EPS        19
# Greens, high EPS     15
# Glucose, high EPS     9
# P only, con           6
# T+P                   1
# Name: Ferm Condition, dtype: int64

# %%
mapping_ferm_cond = {
    'Tryptone+Peptone': 'T+P',
    'Tryptone only': 'T only',
    'Glucose': 'Glucose, no EPS',
    'Glucose, no EPS, CR': 'Glucose, no EPS',
    'Peptone only, upconcentrated': 'P only, con',
    'Potato peptone and tryptone, high viscosity by post-ferm addition of 0.7% XG': 'T+P, 0.7% XG',
    'Peptone only': 'P only',
    'Potato peptone and tryptone, low viscosity': 'T+P',
    'Glucose, high EPS, CR': 'Glucose, high EPS',
    'tryptone only': 'T only',
    'repeat of P080-22-Y007, tryptone + potato peptone': 'T+P',
    'Tryptone + potato peptone, lower top feed rate, no EPS': 'T+P',
    'tryptone + potato peptone, low top feed rate, no EPS, w 0.7% XG': 'T+P, 0.7% XG',
    'repeat of P080-22-Y005, tryptone + potato peptone': 'T+P',
    'Potato peptone only, less EPS, pH control': 'P only',
    'Glucose, no EPS': 'Glucose, no EPS',
    'Glucose, high EPS, CR broth': 'Glucose, high EPS',
    'Greens': 'Greens, high EPS',
    'Glucose, high EPS': 'Glucose, no EPS'
}

# %%
# Iterate through the column and replace values
for i in range(len(info_df['Ferm condition'])):
    if info_df['Ferm condition'][i] in mapping_ferm_cond:
        info_df['Ferm condition'][i] = mapping_ferm_cond[info_df['Ferm condition'][i]]

# %%
info_df.head()
# Out:
#   FD sample ID     FD Run ID                Strain Ferm condition Cryo mix
# 0  22PT1202-10  FDL-105A-T01  Klebsiella variicola   T+P, 0.7% XG      SKP
# 1  22PT1202-12  FDL-105A-T02  Klebsiella variicola   T+P, 0.7% XG      DSR
# 2   22PT1202-5  FDL-105A-T03    Kosakonia sacchari   T+P, 0.7% XG   PVT70%
# 3  22PT1202-11  FDL-105A-T04  Klebsiella variicola   T+P, 0.7% XG   PVT70%
# 4   22PT1202-1  FDL-105B-T05    Kosakonia sacchari            T+P      SKP

# %%
info_df['Ferm condition'].value_counts()
# Out:
# T+P                  26
# Glucose, no EPS      23
# T only               13
# T+P, 0.7% XG          9
# Glucose, high EPS     9
# P only                9
# P only, con           7
# Greens, high EPS      1
# Name: Ferm condition, dtype: int64

# %%
info_df.shape
# Out:
# (97, 5)

# %%
info_df['FD sample ID'].value_counts()
# Out:
# 23PT0406-KLUB    11
# 23PT0227-8        7
# 23PT0227-6        6
# 23PT0227-4        6
# 22PT1202-10       1
#                  ..
# 23PT0119-5        1
# 23PT0119-3        1
# 23PT0119-2        1
# 22PT1117-4        1
# 23PT0405-KOKO     1
# Name: FD sample ID, Length: 71, dtype: int64

# %%
info_df[info_df['FD sample ID']=='23PT0227-6']
# Out:
#    FD sample ID      FD Run ID              Strain Ferm condition Cryo mix
# 64   23PT0227-6   FDL-111A-T03  Kosakonia sacchari         P only   PVT70%
# 68   23PT0227-6   FDL-111C-T11  Kosakonia sacchari         P only   PVT70%
# 72   23PT0227-6   FDL-111D-T15  Kosakonia sacchari         P only   PVT70%
# 75   23PT0227-6  FDL-111EF-T19  Kosakonia sacchari         P only   PVT70%
# 79   23PT0227-6   FDL-111G-T23  Kosakonia sacchari         P only   PVT70%
# 83   23PT0227-6   FDL-111H-T27  Kosakonia sacchari         P only   PVT70%

# %% [markdown]
# **Insights**: each parent has unique Strain, Ferm condition, and Cryo mix
#
# - The children are different from each other by FD Run ID and FD recipe but it doesn't important

# %% [markdown]
# **In-pack CFU TO MERGE**

# %% [markdown]
# The actual cfu df from the web app will be decay_t2_final, processed from Inpack_CFU_Test.csv file
#
# *To-do* in the web app:
# 1. Drop 'T0' and 'Date' before merging
# 2. Incorportate thefuzz to calculate the ratio naming in case human errors from data entry

# %%
# Use decay_t3_final for now as the test
decay_t3_final.head()
# Out:
#             FD Run ID             0            14            28  56  84  \
# 0   FDL-105EF-T24-CC1  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1   FDL-105EF-T24-CC2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2   FDL-105EF-T24-SO1  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3   FDL-105EF-T24-SO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4  FDL-105EF-T24-TMC1  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper
# 0   11.095780   0.884324   -0.079040    0.050789
# 1   11.119291   0.943177   -0.066643    0.034282
# 2   11.078498   0.965821   -0.053539    0.021955
# 3   11.089304   0.999838   -0.023865   -0.017218
# 4   11.151777   0.746866   -0.173616    0.132266

# %%
cfu_df = decay_t3_final.copy()

# %%
cfu_df.shape
# Out:
# (56, 10)

# %% [markdown]
# **In-pack USER INPUT TO MERGE**

# %% [markdown]
# *To-do* in the web app:
# 1. Col name: 'Temperature (C)' - no degree sign

# %% [markdown]
# *To-do* for the historical data:
# 1. Col name: 'Temperature (C)' - no degree sign
# 2. Strip all spaces in 'Desiccant' col

# %%
cols = ['FD sample ID', 'FD Run ID','Storage form','Container','Temperature (°C)','Bulking','Desiccant']
real_input_df = inpack_df[cols]

# %%
real_input_df.head()
# Out:
#     FD sample ID FD Run ID                      Storage form Container  \
# 0  IFF09152022-1  FDL-099A                            Pellet     Mylar
# 1  IFF09152022-1  FDL-099A                            Pellet     Mylar
# 2  IFF09152022-1  FDL-099A                   Unbulked powder     Mylar
# 3  IFF09152022-1  FDL-099A  Bulked powder, pre-dried bulking     Mylar
# 4  IFF09152022-1  FDL-099A           Bulked powder, w/o SiO2     Mylar
#
#    Temperature (°C) Bulking Desiccant
# 0                21     PVT         N
# 1                21     PVT   2%CaCl2
# 2                21     PVT    5%SIO2
# 3                21     PVT    5%SIO2
# 4                21     PVT    5%SIO2

# %%
# Use the sub group of id_to_test (the samples with unique ids to pivot -> calculate decay)
real_input_df = real_input_df[real_input_df['FD Run ID'].isin(id_to_test)]

# %%
real_input_df['Desiccant'].unique()
# Out:
# array(['2%CaCl2', '10%CaCl2', '10%SIO2', '25%SIO2', '5%TMC', '25%TMC',
#        '10%TMC', '5%SIO2', '5%TMC+2%CaCl2', '2% CaCl2', '5%TMC+2% CaCl2'],
#       dtype=object)

# %%
# remove all spaces for 'Desiccant' col
real_input_df['Desiccant'] = real_input_df['Desiccant'].apply(lambda x:x.strip().replace(" ", ""))

# %%
real_input_df['FD Run ID'].value_counts()
# Out:
# FDL-111EF-T19-TMC1       2
# FDL-111G-T23             2
# FDL-111G-T22-CC1TMC1     2
# FDL-111G-T22             2
# FDL-111G-T23-CC1TMC1     2
# FDL-111EF-T19-CC1TMC1    2
# FDL-111EF-T19            2
# FDL-111EF-T18-TMC1       2
# FDL-111EF-T18-CC1TMC1    2
# FDL-111EF-T18            2
# FDL-111G-T22-TMC1        2
# FDL-111B-T8-TMC1         1
# FDL-111G-T23-TMC1        1
# FDL-105K-T44             1
# FDL-105K-T42             1
# FDL-111D-T15             1
# FDL-111D-T15-TMC1        1
# FDL-111D-T15-CC1         1
# FDL-111D-T14             1
# FDL-111D-T14-TMC1        1
# FDL-111D-T14-CC1         1
# FDL-111A-T2              1
# FDL-111B-T8-CC1          1
# FDL-111A-T2-TMC1         1
# FDL-111A-T2-TMC2         1
# FDL-111A-T3              1
# FDL-111A-T3-TMC1         1
# FDL-111B-T8              1
# FDL-111A-T4              1
# FDL-111A-T4-TMC1         1
# FDL-111A-T4-TMC2         1
# FDL-111A-T3-TMC2         1
# FDL-105EF-T24-CC1        1
# FDL-105EF-T24-CC2        1
# FDL-105EF-T26-TMC2       1
# FDL-105EF-T24-SO1        1
# FDL-105EF-T24-SO2        1
# FDL-105EF-T24-TMC1       1
# FDL-105EF-T24-TMC2       1
# FDL-105B-T10-CC1         1
# FDL-105B-T10-CC2         1
# FDL-105EF-T26-CC1        1
# FDL-105EF-T26-CC2        1
# FDL-105EF-T26-TMC1       1
# FDL-105EF-T26-SO1        1
# FDL-105G-T33-Try         1
# FDL-105EF-T26-SO2        1
# FDL-105EF-T22-Try        1
# FDL-105EF-T24-SKP        1
# FDL-105B-T10-SKP         1
# FDL-105B-T10-Try         1
# FDL-105C-T15-SKP         1
# FDL-105C-T15-Try         1
# FDL-105C-T14-Try         1
# FDL-105D-T20-Try         1
# FDL-111G T23 TMC1        1
# Name: FD Run ID, dtype: int64

# %%
real_input_df.shape
# Out:
# (67, 7)

# %%
real_input_df[real_input_df.duplicated()]
# Out:
#     FD sample ID              FD Run ID   Storage form Container  \
# 174   23PT0227-4         FDL-111EF-T18   Bulked powder     Mylar
# 175   23PT0227-4  FDL-111EF-T18-CC1TMC1  Bulked powder     Mylar
# 176   23PT0227-4     FDL-111EF-T18-TMC1  Bulked powder     Mylar
# 177   23PT0227-6          FDL-111EF-T19  Bulked powder     Mylar
# 178   23PT0227-6  FDL-111EF-T19-CC1TMC1  Bulked powder     Mylar
# 179   23PT0227-6     FDL-111EF-T19-TMC1  Bulked powder     Mylar
# 180   23PT0227-4           FDL-111G-T22  Bulked powder     Mylar
# 181   23PT0227-4   FDL-111G-T22-CC1TMC1  Bulked powder     Mylar
# 182   23PT0227-4      FDL-111G-T22-TMC1  Bulked powder     Mylar
# 183   23PT0227-6          FDL-111G-T23   Bulked powder     Mylar
# 184   23PT0227-6   FDL-111G-T23-CC1TMC1  Bulked powder     Mylar
#
#      Temperature (°C) Bulking      Desiccant
# 174                21     PVT         5%SIO2
# 175                21     PVT  5%TMC+2%CaCl2
# 176                21     PVT          5%TMC
# 177                21     PVT         5%SIO2
# 178                21     PVT  5%TMC+2%CaCl2
# 179                21     PVT          5%TMC
# 180                21     PVT         5%SIO2
# 181                21     PVT  5%TMC+2%CaCl2
# 182                21     PVT          5%TMC
# 183                21     PVT         5%SIO2
# 184                21     PVT  5%TMC+2%CaCl2

# %%
real_input_df.drop_duplicates(inplace=True)

# %%
real_input_df.shape
# Out:
# (56, 7)

# %% [markdown]
# ## C. Join the Dataframes
#
# 1. real_input_df + decay_df ON 'FD Run ID' = A
# 2. A + info_df ON 'FD sample ID' = B

# %% [markdown]
# **NOTE**
#
# MUST have the USER INPUT of *"FD sample ID"* to merge the dfs, because
# - cfu_df (decay_df) doesn't have FD sample ID
# - info_df doesn't contain all the FD Run ID
#
# Thus, can't merge on FD Run ID from these 2 dfs.

# %%
info_df.shape, real_input_df.shape, cfu_df.shape
# Out:
# ((97, 5), (56, 7), (56, 10))

# %%
same_ids = real_input_df[real_input_df['FD Run ID'].isin(cfu_df['FD Run ID'])]

# %%
same_ids.shape
# Out:
# (56, 7)

# %% [markdown]
# temp1 = real_input_df + decay_df ON 'FD Run ID'

# %%
temp1 = pd.merge(left=real_input_df, right=cfu_df, on='FD Run ID', how='left')

# %%
temp1.head()
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
#
#   Bulking Desiccant             0            14            28  56  84  \
# 0     PVT   2%CaCl2  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1     PVT  10%CaCl2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2     PVT   10%SIO2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3     PVT   25%SIO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4     PVT     5%TMC  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper
# 0   11.095780   0.884324   -0.079040    0.050789
# 1   11.119291   0.943177   -0.066643    0.034282
# 2   11.078498   0.965821   -0.053539    0.021955
# 3   11.089304   0.999838   -0.023865   -0.017218
# 4   11.151777   0.746866   -0.173616    0.132266

# %%
temp1.shape
# Out:
# (56, 16)

# %% [markdown]
# ---

# %% [markdown]
# temp1 + info_df ON 'FD sample ID' = temp2

# %%
temp2 = pd.merge(left=temp1, right=info_df, on=['FD sample ID', 'FD Run ID'], how='left')

# %%
temp2.head()
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
#
#   Bulking Desiccant             0            14            28  56  84  \
# 0     PVT   2%CaCl2  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1     PVT  10%CaCl2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2     PVT   10%SIO2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3     PVT   25%SIO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4     PVT     5%TMC  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper Strain Ferm condition  \
# 0   11.095780   0.884324   -0.079040    0.050789    NaN            NaN
# 1   11.119291   0.943177   -0.066643    0.034282    NaN            NaN
# 2   11.078498   0.965821   -0.053539    0.021955    NaN            NaN
# 3   11.089304   0.999838   -0.023865   -0.017218    NaN            NaN
# 4   11.151777   0.746866   -0.173616    0.132266    NaN            NaN
#
#   Cryo mix
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
temp2.shape
# Out:
# (56, 19)

# %%
sns.heatmap(temp2.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Note**: Ferm condition, Cryo mix, and Strain don't show after merging because the exact ['FD sample ID', 'FD Run ID'] don't always exist in info_df

# %%
temp2.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['FD sample ID', 'FD Run ID', 'Storage form', 'Container',
#        'Temperature (°C)', 'Bulking', 'Desiccant', '0', '14', '28', '56', '84',
#        'Decay Rate', 'R-squared', 'CI95_lower', 'CI95_upper', 'FD recipe',
#        'Strain', 'Ferm condition', 'Cryo mix'],
#       dtype='object')>

# %%
temp2 = temp2[['FD sample ID', 'FD Run ID', 'Strain', 'Ferm condition', 'Cryo mix',
               'Storage form', 'Container', 'Temperature (°C)', 'Bulking', 'Desiccant', 
               '0', '14', '28', '56', '84', 'Decay Rate', 'R-squared', 'CI95_lower', 'CI95_upper']]

# %%
temp2.sort_values(by='FD sample ID')
# Out:
#    FD sample ID              FD Run ID   Storage form Container  \
# 21   22PT1102-7       FDL-105D-T20-Try  Bulked powder     Mylar
# 20   22PT1102-8       FDL-105C-T14-Try  Bulked powder     Mylar
# 19   22PT1117-5       FDL-105C-T15-Try  Bulked powder     Mylar
# 18   22PT1117-5       FDL-105C-T15-SKP  Bulked powder     Mylar
# 17   22PT1117-8       FDL-105B-T10-Try  Bulked powder     Mylar
# 6    22PT1117-8       FDL-105B-T10-CC1  Bulked powder     Mylar
# 7    22PT1117-8       FDL-105B-T10-CC2  Bulked powder     Mylar
# 16   22PT1117-8       FDL-105B-T10-SKP  Bulked powder     Mylar
# 14   23PT0119-2      FDL-105EF-T22-Try  Bulked powder     Mylar
# 22   23PT0119-4       FDL-105G-T33-Try  Bulked powder     Mylar
# 15   23PT0119-5      FDL-105EF-T24-SKP  Bulked powder     Mylar
# 0    23PT0119-5      FDL-105EF-T24-CC1  Bulked powder     Mylar
# 3    23PT0119-5      FDL-105EF-T24-SO2  Bulked powder     Mylar
# 1    23PT0119-5      FDL-105EF-T24-CC2  Bulked powder     Mylar
# 2    23PT0119-5      FDL-105EF-T24-SO1  Bulked powder     Mylar
# 4    23PT0119-5     FDL-105EF-T24-TMC1  Bulked powder     Mylar
# 5    23PT0119-5     FDL-105EF-T24-TMC2  Bulked powder     Mylar
# 11   23PT0119-8     FDL-105EF-T26-TMC2  Bulked powder     Mylar
# 12   23PT0119-8      FDL-105EF-T26-SO1  Bulked powder     Mylar
# 9    23PT0119-8      FDL-105EF-T26-CC2  Bulked powder     Mylar
# 10   23PT0119-8     FDL-105EF-T26-TMC1  Bulked powder     Mylar
# 13   23PT0119-8      FDL-105EF-T26-SO2  Bulked powder     Mylar
# 8    23PT0119-8      FDL-105EF-T26-CC1  Bulked powder     Mylar
# 53   23PT0126-2           FDL-105K-T42  Bulked powder     Mylar
# 54   23PT0126-5           FDL-105K-T44  Bulked powder     Mylar
# 37   23PT0227-4       FDL-111A-T2-TMC2  Bulked powder     Mylar
# 49   23PT0227-4           FDL-111D-T14  Bulked powder     Mylar
# 36   23PT0227-4       FDL-111A-T2-TMC1  Bulked powder     Mylar
# 35   23PT0227-4            FDL-111A-T2  Bulked powder     Mylar
# 31   23PT0227-4      FDL-111G-T22-TMC1  Bulked powder     Mylar
# 25   23PT0227-4     FDL-111EF-T18-TMC1  Bulked powder     Mylar
# 29   23PT0227-4           FDL-111G-T22  Bulked powder     Mylar
# 24   23PT0227-4  FDL-111EF-T18-CC1TMC1  Bulked powder     Mylar
# 23   23PT0227-4         FDL-111EF-T18   Bulked powder     Mylar
# 48   23PT0227-4      FDL-111D-T14-TMC1  Bulked powder     Mylar
# 30   23PT0227-4   FDL-111G-T22-CC1TMC1  Bulked powder     Mylar
# 47   23PT0227-4       FDL-111D-T14-CC1  Bulked powder     Mylar
# 51   23PT0227-6      FDL-111D-T15-TMC1  Bulked powder     Mylar
# 50   23PT0227-6       FDL-111D-T15-CC1  Bulked powder     Mylar
# 52   23PT0227-6           FDL-111D-T15  Bulked powder     Mylar
# 27   23PT0227-6  FDL-111EF-T19-CC1TMC1  Bulked powder     Mylar
# 39   23PT0227-6       FDL-111A-T3-TMC1  Bulked powder     Mylar
# 38   23PT0227-6            FDL-111A-T3  Bulked powder     Mylar
# 34   23PT0227-6      FDL-111G-T23-TMC1  Bulked powder     Mylar
# 33   23PT0227-6   FDL-111G-T23-CC1TMC1  Bulked powder     Mylar
# 32   23PT0227-6          FDL-111G-T23   Bulked powder     Mylar
# 28   23PT0227-6     FDL-111EF-T19-TMC1  Bulked powder     Mylar
# 26   23PT0227-6          FDL-111EF-T19  Bulked powder     Mylar
# 40   23PT0227-6       FDL-111A-T3-TMC2  Bulked powder     Mylar
# 55   23PT0227-6      FDL-111G T23 TMC1  Bulked powder     Mylar
# 41   23PT0227-8            FDL-111A-T4  Bulked powder     Mylar
# 42   23PT0227-8       FDL-111A-T4-TMC1  Bulked powder     Mylar
# 43   23PT0227-8       FDL-111A-T4-TMC2  Bulked powder     Mylar
# 44   23PT0227-8        FDL-111B-T8-CC1  Bulked powder     Mylar
# 45   23PT0227-8       FDL-111B-T8-TMC1  Bulked powder     Mylar
# 46   23PT0227-8            FDL-111B-T8  Bulked powder     Mylar
#
#     Temperature (°C)   Bulking      Desiccant             0            14  \
# 21                21  Tryptone         5%SIO2  1.178000e+11           NaN
# 20                21  Tryptone         5%SIO2  1.000667e+11           NaN
# 19                21  Tryptone         5%SIO2  6.502222e+10           NaN
# 18                21       SKP         5%SIO2  6.502222e+10           NaN
# 17                21  Tryptone         5%SIO2           NaN           NaN
# 6                 21       PVT        2%CaCl2  1.260333e+11  1.026000e+11
# 7                 21       PVT       10%CaCl2  1.406000e+11  1.336333e+11
# 16                21       SKP         5%SIO2           NaN           NaN
# 14                21  Tryptone         5%SIO2  9.204444e+10           NaN
# 22                21  Tryptone         5%SIO2  5.151111e+10           NaN
# 15                21       SKP         5%SIO2  1.068222e+11           NaN
# 0                 21       PVT        2%CaCl2  1.133667e+11  9.563333e+10
# 3                 21       PVT        25%SIO2  1.222333e+11  6.396667e+10
# 1                 21       PVT       10%CaCl2  1.222333e+11  9.056667e+10
# 2                 21       PVT        10%SIO2  1.133667e+11  8.043333e+10
# 4                 21       PVT          5%TMC  1.133667e+11  1.140000e+11
# 5                 21       PVT         25%TMC  1.222333e+11  1.000667e+11
# 11                21       PVT         25%TMC  8.782222e+10  5.742222e+10
# 12                21       PVT        10%SIO2  7.177778e+10  5.362222e+10
# 9                 21       PVT       10%CaCl2  1.034444e+11  9.500000e+10
# 10                21       PVT         10%TMC  1.013333e+11  7.853333e+10
# 13                21       PVT        25%SIO2  5.531111e+10  4.348889e+10
# 8                 21       PVT        2%CaCl2  1.169556e+11  8.993333e+10
# 53                21       PVT         5%SIO2  3.546667e+10           NaN
# 54                21       PVT         5%SIO2  6.840000e+10           NaN
# 37                21       PVT         25%TMC  1.257800e+10  2.774000e+08
# 49                21       PVT         5%SIO2  1.072444e+11  5.826667e+09
# 36                21       PVT          5%TMC  1.257800e+10  1.869600e+09
# 35                21       PVT         5%SIO2  1.105800e+10  1.147600e+09
# 31                21       PVT          5%TMC  6.417778e+10           NaN
# 25                21       PVT          5%TMC  8.444444e+10           NaN
# 29                21       PVT         5%SIO2  7.304444e+10           NaN
# 24                21       PVT  5%TMC+2%CaCl2  1.009111e+11           NaN
# 23                21       PVT         5%SIO2  8.740000e+10           NaN
# 48                21       PVT          5%TMC  1.266667e+11  9.880000e+09
# 30                21       PVT  5%TMC+2%CaCl2  7.600000e+10           NaN
# 47                21       PVT        2%CaCl2  1.292000e+11  1.216000e+10
# 51                21       PVT          5%TMC  1.414444e+11  2.660000e+10
# 50                21       PVT        2%CaCl2  1.498889e+11  3.597333e+10
# 52                21       PVT         5%SIO2  1.574889e+11  2.204000e+10
# 27                21       PVT  5%TMC+2%CaCl2  1.427111e+11           NaN
# 39                21       PVT          5%TMC  1.960800e+10  3.458000e+09
# 38                21       PVT         5%SIO2  1.953200e+10  2.698000e+09
# 34                21       PVT          5%TMC  7.895556e+10           NaN
# 33                21       PVT  5%TMC+2%CaCl2  7.811111e+10           NaN
# 32                21       PVT         5%SIO2  7.388889e+10           NaN
# 28                21       PVT          5%TMC  1.072444e+11           NaN
# 26                21       PVT         5%SIO2  1.089333e+11           NaN
# 40                21       PVT         25%TMC  1.960800e+10  4.218000e+09
# 55                21       PVT          5%TMC  7.895556e+10           NaN
# 41                21       PVT         5%SIO2  2.432000e+09  2.660000e+08
# 42                21       PVT          5%TMC  1.748000e+09  2.964000e+08
# 43                21       PVT         25%TMC  1.748000e+09  3.762000e+08
# 44                21       PVT        2%CaCl2  1.511556e+11  3.724000e+10
# 45                21       PVT          5%TMC  1.748000e+11  2.685333e+10
# 46                21       PVT         5%SIO2  1.389111e+11  1.798667e+10
#
#               28            56  84  Decay Rate  R-squared  CI95_lower  \
# 21  8.064444e+10  6.291111e+10 NaN   11.061691   0.985754   -0.012295
# 20  9.035556e+10  4.686667e+10 NaN   11.040415   0.848867   -0.037421
# 19  2.744444e+10  7.177778e+09 NaN   10.847705   0.984521   -0.044320
# 18  2.660000e+10  8.022222e+09 NaN   10.835130   0.992974   -0.033573
# 17  3.293333e+10  2.153333e+10 NaN         NaN        NaN         NaN
# 6   8.191111e+10           NaN NaN   11.101897   0.999318   -0.008902
# 7   9.162222e+10           NaN NaN   11.171626   0.837602   -0.043805
# 16  6.797778e+10  4.137778e+10 NaN         NaN        NaN         NaN
# 14  5.742222e+10           NaN NaN         NaN        NaN         NaN
# 22  3.420000e+10  1.604444e+10 NaN   10.737039   0.971299   -0.028804
# 15  3.800000e+10           NaN NaN         NaN        NaN         NaN
# 0   4.560000e+10           NaN NaN   11.095780   0.884324   -0.079040
# 3   3.251111e+10           NaN NaN   11.089304   0.999838   -0.023865
# 1   4.306667e+10           NaN NaN   11.119291   0.943177   -0.066643
# 2   4.095556e+10           NaN NaN   11.078498   0.965821   -0.053539
# 4   2.989333e+10           NaN NaN   11.151777   0.746866   -0.173616
# 5   4.028000e+10           NaN NaN   11.138573   0.880036   -0.097992
# 11  3.926667e+10           NaN NaN   10.940360   0.998967   -0.017586
# 12  3.504444e+10           NaN NaN   10.865670   0.988535   -0.026337
# 9   7.557778e+10           NaN NaN   11.025098   0.934815   -0.021203
# 10  7.262222e+10           NaN NaN   10.992967   0.914318   -0.025266
# 13  2.575556e+10           NaN NaN   10.763325   0.956185   -0.044100
# 8   7.304444e+10           NaN NaN   11.064060   0.995515   -0.013528
# 53  7.650667e+09           NaN NaN         NaN        NaN         NaN
# 54  2.153333e+09           NaN NaN         NaN        NaN         NaN
# 37           NaN           NaN NaN         NaN        NaN         NaN
# 49           NaN           NaN NaN         NaN        NaN         NaN
# 36           NaN           NaN NaN         NaN        NaN         NaN
# 35           NaN           NaN NaN         NaN        NaN         NaN
# 31           NaN           NaN NaN         NaN        NaN         NaN
# 25           NaN           NaN NaN         NaN        NaN         NaN
# 29           NaN           NaN NaN         NaN        NaN         NaN
# 24           NaN           NaN NaN         NaN        NaN         NaN
# 23           NaN           NaN NaN         NaN        NaN         NaN
# 48           NaN           NaN NaN         NaN        NaN         NaN
# 30           NaN           NaN NaN         NaN        NaN         NaN
# 47           NaN           NaN NaN         NaN        NaN         NaN
# 51           NaN           NaN NaN         NaN        NaN         NaN
# 50           NaN           NaN NaN         NaN        NaN         NaN
# 52           NaN           NaN NaN         NaN        NaN         NaN
# 27           NaN           NaN NaN         NaN        NaN         NaN
# 39           NaN           NaN NaN         NaN        NaN         NaN
# 38           NaN           NaN NaN         NaN        NaN         NaN
# 34           NaN           NaN NaN         NaN        NaN         NaN
# 33           NaN           NaN NaN         NaN        NaN         NaN
# 32           NaN           NaN NaN         NaN        NaN         NaN
# 28           NaN           NaN NaN         NaN        NaN         NaN
# 26           NaN           NaN NaN         NaN        NaN         NaN
# 40           NaN           NaN NaN         NaN        NaN         NaN
# 55           NaN           NaN NaN         NaN        NaN         NaN
# 41           NaN           NaN NaN         NaN        NaN         NaN
# 42           NaN           NaN NaN         NaN        NaN         NaN
# 43           NaN           NaN NaN         NaN        NaN         NaN
# 44           NaN           NaN NaN         NaN        NaN         NaN
# 45           NaN           NaN NaN         NaN        NaN         NaN
# 46           NaN           NaN NaN         NaN        NaN         NaN
#
#     CI95_upper              Strain Ferm condition Cryo mix
# 21    0.002566                 NaN            NaN      NaN
# 20    0.025656                 NaN            NaN      NaN
# 19    0.010138                 NaN            NaN      NaN
# 18    0.001117                 NaN            NaN      NaN
# 17         NaN                 NaN            NaN      NaN
# 6    -0.004465                 NaN            NaN      NaN
# 7     0.030520                 NaN            NaN      NaN
# 16         NaN                 NaN            NaN      NaN
# 14         NaN                 NaN            NaN      NaN
# 22    0.010712                 NaN            NaN      NaN
# 15         NaN                 NaN            NaN      NaN
# 0     0.050789                 NaN            NaN      NaN
# 3    -0.017218                 NaN            NaN      NaN
# 1     0.034282                 NaN            NaN      NaN
# 2     0.021955                 NaN            NaN      NaN
# 4     0.132266                 NaN            NaN      NaN
# 5     0.063556                 NaN            NaN      NaN
# 11   -0.007384                 NaN            NaN      NaN
# 12    0.004097                 NaN            NaN      NaN
# 9     0.011466                 NaN            NaN      NaN
# 10    0.014932                 NaN            NaN      NaN
# 13    0.020390                 NaN            NaN      NaN
# 8    -0.001074                 NaN            NaN      NaN
# 53         NaN  Kosakonia sacchari            T+P   PVT70%
# 54         NaN  Kosakonia sacchari   T+P, 0.7% XG   PVT70%
# 37         NaN                 NaN            NaN      NaN
# 49         NaN  Kosakonia sacchari         T only   PVT70%
# 36         NaN                 NaN            NaN      NaN
# 35         NaN                 NaN            NaN      NaN
# 31         NaN                 NaN            NaN      NaN
# 25         NaN                 NaN            NaN      NaN
# 29         NaN  Kosakonia sacchari         T only   PVT70%
# 24         NaN                 NaN            NaN      NaN
# 23         NaN                 NaN            NaN      NaN
# 48         NaN                 NaN            NaN      NaN
# 30         NaN                 NaN            NaN      NaN
# 47         NaN                 NaN            NaN      NaN
# 51         NaN                 NaN            NaN      NaN
# 50         NaN                 NaN            NaN      NaN
# 52         NaN  Kosakonia sacchari         P only   PVT70%
# 27         NaN                 NaN            NaN      NaN
# 39         NaN                 NaN            NaN      NaN
# 38         NaN                 NaN            NaN      NaN
# 34         NaN                 NaN            NaN      NaN
# 33         NaN                 NaN            NaN      NaN
# 32         NaN                 NaN            NaN      NaN
# 28         NaN                 NaN            NaN      NaN
# 26         NaN  Kosakonia sacchari         P only   PVT70%
# 40         NaN                 NaN            NaN      NaN
# 55         NaN                 NaN            NaN      NaN
# 41         NaN                 NaN            NaN      NaN
# 42         NaN                 NaN            NaN      NaN
# 43         NaN                 NaN            NaN      NaN
# 44         NaN                 NaN            NaN      NaN
# 45         NaN                 NaN            NaN      NaN
# 46         NaN                 NaN            NaN      NaN

# %%
temp2.sort_values(by='FD sample ID')['FD sample ID'].value_counts()
# Out:
# 23PT0227-6    13
# 23PT0227-4    12
# 23PT0119-5     7
# 23PT0119-8     6
# 23PT0227-8     6
# 22PT1117-8     4
# 22PT1117-5     2
# 22PT1102-7     1
# 22PT1102-8     1
# 23PT0119-2     1
# 23PT0119-4     1
# 23PT0126-2     1
# 23PT0126-5     1
# Name: FD sample ID, dtype: int64

# %% [markdown]
# **Q: Why don't values from `info_df` show in the merged df??**
#
# A: The  (e.g. No 23PT0119-5 and 105EF-T24, only the derivative of 105EF-T24)

# %% [markdown]
# Unit test 1

# %%
info_df[info_df['FD sample ID']=='23PT0119-5']
# Out:
#    FD sample ID  FD Run ID              Strain Ferm condition Cryo mix
# 23   23PT0119-5  105EF-T24  Kosakonia sacchari         T only   PVT70%

# %%
temp2[temp2['FD sample ID']=='23PT0119-5']
# Out:
#    FD sample ID           FD Run ID   Storage form Container  \
# 0    23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar
# 1    23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar
# 2    23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar
# 3    23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar
# 4    23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar
# 5    23PT0119-5  FDL-105EF-T24-TMC2  Bulked powder     Mylar
# 15   23PT0119-5   FDL-105EF-T24-SKP  Bulked powder     Mylar
#
#     Temperature (°C) Bulking Desiccant             0            14  \
# 0                 21     PVT   2%CaCl2  1.133667e+11  9.563333e+10
# 1                 21     PVT  10%CaCl2  1.222333e+11  9.056667e+10
# 2                 21     PVT   10%SIO2  1.133667e+11  8.043333e+10
# 3                 21     PVT   25%SIO2  1.222333e+11  6.396667e+10
# 4                 21     PVT     5%TMC  1.133667e+11  1.140000e+11
# 5                 21     PVT    25%TMC  1.222333e+11  1.000667e+11
# 15                21     SKP    5%SIO2  1.068222e+11           NaN
#
#               28  56  84  Decay Rate  R-squared  CI95_lower  CI95_upper  \
# 0   4.560000e+10 NaN NaN   11.095780   0.884324   -0.079040    0.050789
# 1   4.306667e+10 NaN NaN   11.119291   0.943177   -0.066643    0.034282
# 2   4.095556e+10 NaN NaN   11.078498   0.965821   -0.053539    0.021955
# 3   3.251111e+10 NaN NaN   11.089304   0.999838   -0.023865   -0.017218
# 4   2.989333e+10 NaN NaN   11.151777   0.746866   -0.173616    0.132266
# 5   4.028000e+10 NaN NaN   11.138573   0.880036   -0.097992    0.063556
# 15  3.800000e+10 NaN NaN         NaN        NaN         NaN         NaN
#
#    Strain Ferm condition Cryo mix
# 0     NaN            NaN      NaN
# 1     NaN            NaN      NaN
# 2     NaN            NaN      NaN
# 3     NaN            NaN      NaN
# 4     NaN            NaN      NaN
# 5     NaN            NaN      NaN
# 15    NaN            NaN      NaN

# %%
merge_1 = temp2[temp2['FD sample ID']=='23PT0119-5']

# %%
merge_1.drop(['Strain','Ferm condition','Cryo mix'],axis=1,inplace=True)

# %%
merge_1 = merge_1.merge(info_df.drop('FD Run ID',axis=1), on='FD sample ID')

# %%
merge_1
# rearrange the cols order later
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
# 5   23PT0119-5  FDL-105EF-T24-TMC2  Bulked powder     Mylar                21
# 6   23PT0119-5   FDL-105EF-T24-SKP  Bulked powder     Mylar                21
#
#   Bulking Desiccant             0            14            28  56  84  \
# 0     PVT   2%CaCl2  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1     PVT  10%CaCl2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2     PVT   10%SIO2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3     PVT   25%SIO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4     PVT     5%TMC  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
# 5     PVT    25%TMC  1.222333e+11  1.000667e+11  4.028000e+10 NaN NaN
# 6     SKP    5%SIO2  1.068222e+11           NaN  3.800000e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper              Strain  \
# 0   11.095780   0.884324   -0.079040    0.050789  Kosakonia sacchari
# 1   11.119291   0.943177   -0.066643    0.034282  Kosakonia sacchari
# 2   11.078498   0.965821   -0.053539    0.021955  Kosakonia sacchari
# 3   11.089304   0.999838   -0.023865   -0.017218  Kosakonia sacchari
# 4   11.151777   0.746866   -0.173616    0.132266  Kosakonia sacchari
# 5   11.138573   0.880036   -0.097992    0.063556  Kosakonia sacchari
# 6         NaN        NaN         NaN         NaN  Kosakonia sacchari
#
#   Ferm condition Cryo mix
# 0         T only   PVT70%
# 1         T only   PVT70%
# 2         T only   PVT70%
# 3         T only   PVT70%
# 4         T only   PVT70%
# 5         T only   PVT70%
# 6         T only   PVT70%

# %% [markdown]
# Unit test 2: **the issue** lies here
# 1. The *info_df* only contains the *children in FD Run ID*
# 2. The *merge_2* contains the *children and grandchildren in FD Run ID*
# 3. A *parent* has many *children* differs in *FD recipe*
#     - how to extract the *children* from the *grandchildren* to pass down the parent's info?

# %%
info_df[info_df['FD sample ID']=='23PT0227-6']
# Out:
#    FD sample ID      FD Run ID              Strain Ferm condition Cryo mix
# 64   23PT0227-6   FDL-111A-T03  Kosakonia sacchari         P only   PVT70%
# 68   23PT0227-6   FDL-111C-T11  Kosakonia sacchari         P only   PVT70%
# 72   23PT0227-6   FDL-111D-T15  Kosakonia sacchari         P only   PVT70%
# 75   23PT0227-6  FDL-111EF-T19  Kosakonia sacchari         P only   PVT70%
# 79   23PT0227-6   FDL-111G-T23  Kosakonia sacchari         P only   PVT70%
# 83   23PT0227-6   FDL-111H-T27  Kosakonia sacchari         P only   PVT70%

# %%
merge_2 = temp2[temp2['FD sample ID']=='23PT0227-6']
merge_2
# Out:
#    FD sample ID              FD Run ID   Storage form Container  \
# 26   23PT0227-6          FDL-111EF-T19  Bulked powder     Mylar
# 27   23PT0227-6  FDL-111EF-T19-CC1TMC1  Bulked powder     Mylar
# 28   23PT0227-6     FDL-111EF-T19-TMC1  Bulked powder     Mylar
# 32   23PT0227-6          FDL-111G-T23   Bulked powder     Mylar
# 33   23PT0227-6   FDL-111G-T23-CC1TMC1  Bulked powder     Mylar
# 34   23PT0227-6      FDL-111G-T23-TMC1  Bulked powder     Mylar
# 38   23PT0227-6            FDL-111A-T3  Bulked powder     Mylar
# 39   23PT0227-6       FDL-111A-T3-TMC1  Bulked powder     Mylar
# 40   23PT0227-6       FDL-111A-T3-TMC2  Bulked powder     Mylar
# 50   23PT0227-6       FDL-111D-T15-CC1  Bulked powder     Mylar
# 51   23PT0227-6      FDL-111D-T15-TMC1  Bulked powder     Mylar
# 52   23PT0227-6           FDL-111D-T15  Bulked powder     Mylar
# 55   23PT0227-6      FDL-111G T23 TMC1  Bulked powder     Mylar
#
#     Temperature (°C) Bulking      Desiccant             0            14  28  \
# 26                21     PVT         5%SIO2  1.089333e+11           NaN NaN
# 27                21     PVT  5%TMC+2%CaCl2  1.427111e+11           NaN NaN
# 28                21     PVT          5%TMC  1.072444e+11           NaN NaN
# 32                21     PVT         5%SIO2  7.388889e+10           NaN NaN
# 33                21     PVT  5%TMC+2%CaCl2  7.811111e+10           NaN NaN
# 34                21     PVT          5%TMC  7.895556e+10           NaN NaN
# 38                21     PVT         5%SIO2  1.953200e+10  2.698000e+09 NaN
# 39                21     PVT          5%TMC  1.960800e+10  3.458000e+09 NaN
# 40                21     PVT         25%TMC  1.960800e+10  4.218000e+09 NaN
# 50                21     PVT        2%CaCl2  1.498889e+11  3.597333e+10 NaN
# 51                21     PVT          5%TMC  1.414444e+11  2.660000e+10 NaN
# 52                21     PVT         5%SIO2  1.574889e+11  2.204000e+10 NaN
# 55                21     PVT          5%TMC  7.895556e+10           NaN NaN
#
#     56  84  Decay Rate  R-squared  CI95_lower  CI95_upper              Strain  \
# 26 NaN NaN         NaN        NaN         NaN         NaN  Kosakonia sacchari
# 27 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 28 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 32 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 33 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 34 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 38 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 39 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 40 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 50 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 51 NaN NaN         NaN        NaN         NaN         NaN                 NaN
# 52 NaN NaN         NaN        NaN         NaN         NaN  Kosakonia sacchari
# 55 NaN NaN         NaN        NaN         NaN         NaN                 NaN
#
#    Ferm condition Cryo mix
# 26         P only   PVT70%
# 27            NaN      NaN
# 28            NaN      NaN
# 32            NaN      NaN
# 33            NaN      NaN
# 34            NaN      NaN
# 38            NaN      NaN
# 39            NaN      NaN
# 40            NaN      NaN
# 50            NaN      NaN
# 51            NaN      NaN
# 52         P only   PVT70%
# 55            NaN      NaN

# %%
merge_2.shape
# Out:
# (13, 19)

# %%
merge_2.drop(['Strain','Ferm condition','Cryo mix'],axis=1,inplace=True)

# %%
merge_2 = merge_2.merge(info_df.drop('FD Run ID',axis=1), on='FD sample ID')

# %%
merge_2
# rearrange the cols order later
# Out:
#    FD sample ID          FD Run ID   Storage form Container  Temperature (°C)  \
# 0    23PT0227-6      FDL-111EF-T19  Bulked powder     Mylar                21
# 1    23PT0227-6      FDL-111EF-T19  Bulked powder     Mylar                21
# 2    23PT0227-6      FDL-111EF-T19  Bulked powder     Mylar                21
# 3    23PT0227-6      FDL-111EF-T19  Bulked powder     Mylar                21
# 4    23PT0227-6      FDL-111EF-T19  Bulked powder     Mylar                21
# ..          ...                ...            ...       ...               ...
# 73   23PT0227-6  FDL-111G T23 TMC1  Bulked powder     Mylar                21
# 74   23PT0227-6  FDL-111G T23 TMC1  Bulked powder     Mylar                21
# 75   23PT0227-6  FDL-111G T23 TMC1  Bulked powder     Mylar                21
# 76   23PT0227-6  FDL-111G T23 TMC1  Bulked powder     Mylar                21
# 77   23PT0227-6  FDL-111G T23 TMC1  Bulked powder     Mylar                21
#
#    Bulking Desiccant             0  14  28  56  84  Decay Rate  R-squared  \
# 0      PVT    5%SIO2  1.089333e+11 NaN NaN NaN NaN         NaN        NaN
# 1      PVT    5%SIO2  1.089333e+11 NaN NaN NaN NaN         NaN        NaN
# 2      PVT    5%SIO2  1.089333e+11 NaN NaN NaN NaN         NaN        NaN
# 3      PVT    5%SIO2  1.089333e+11 NaN NaN NaN NaN         NaN        NaN
# 4      PVT    5%SIO2  1.089333e+11 NaN NaN NaN NaN         NaN        NaN
# ..     ...       ...           ...  ..  ..  ..  ..         ...        ...
# 73     PVT     5%TMC  7.895556e+10 NaN NaN NaN NaN         NaN        NaN
# 74     PVT     5%TMC  7.895556e+10 NaN NaN NaN NaN         NaN        NaN
# 75     PVT     5%TMC  7.895556e+10 NaN NaN NaN NaN         NaN        NaN
# 76     PVT     5%TMC  7.895556e+10 NaN NaN NaN NaN         NaN        NaN
# 77     PVT     5%TMC  7.895556e+10 NaN NaN NaN NaN         NaN        NaN
#
#     CI95_lower  CI95_upper              Strain Ferm condition Cryo mix
# 0          NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 1          NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 2          NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 3          NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 4          NaN         NaN  Kosakonia sacchari         P only   PVT70%
# ..         ...         ...                 ...            ...      ...
# 73         NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 74         NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 75         NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 76         NaN         NaN  Kosakonia sacchari         P only   PVT70%
# 77         NaN         NaN  Kosakonia sacchari         P only   PVT70%
#
# [78 rows x 19 columns]

# %%
merge_2[merge_2.duplicated()].shape
# Out:
# (65, 19)

# %%
# unique merge_2 -> confirm the shape of original merge_2 before merging with info_df
78 - 65
# Out:
# 13

# %% [markdown]
# **SOLUTION**
#
# Each parent has unique Strain, Ferm condition, and Cryo mix regardless different FD Run ID and FD Recipe
#
# -> Drop 'FD Run ID' and 'FD Recipe'
#
# -> Keep the unique 'FD sample ID'

# %%
info_df.head()
# Out:
#   FD sample ID     FD Run ID                Strain Ferm condition Cryo mix
# 0  22PT1202-10  FDL-105A-T01  Klebsiella variicola   T+P, 0.7% XG      SKP
# 1  22PT1202-12  FDL-105A-T02  Klebsiella variicola   T+P, 0.7% XG      DSR
# 2   22PT1202-5  FDL-105A-T03    Kosakonia sacchari   T+P, 0.7% XG   PVT70%
# 3  22PT1202-11  FDL-105A-T04  Klebsiella variicola   T+P, 0.7% XG   PVT70%
# 4   22PT1202-1  FDL-105B-T05    Kosakonia sacchari            T+P      SKP

# %%
info_df.shape
# Out:
# (97, 5)

# %%
info_df.nunique()
# Out:
# FD sample ID      71
# FD Run ID         97
# Strain             2
# Ferm condition     8
# Cryo mix           3
# dtype: int64

# %%
info_to_test = info_df.copy()

# %%
info_to_test.drop(['FD Run ID'],axis=1,inplace=True)

# %%
info_to_test[info_to_test.duplicated()].count()
# Out:
# FD sample ID      26
# Strain            26
# Ferm condition    26
# Cryo mix          26
# dtype: int64

# %%
97-26
# Out:
# 71

# %%
info_to_test = info_to_test.drop_duplicates()

# %% [markdown]
# Test the merge

# %%
temp2.head()
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
#
#   Bulking Desiccant             0            14            28  56  84  \
# 0     PVT   2%CaCl2  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1     PVT  10%CaCl2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2     PVT   10%SIO2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3     PVT   25%SIO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4     PVT     5%TMC  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper Strain Ferm condition  \
# 0   11.095780   0.884324   -0.079040    0.050789    NaN            NaN
# 1   11.119291   0.943177   -0.066643    0.034282    NaN            NaN
# 2   11.078498   0.965821   -0.053539    0.021955    NaN            NaN
# 3   11.089304   0.999838   -0.023865   -0.017218    NaN            NaN
# 4   11.151777   0.746866   -0.173616    0.132266    NaN            NaN
#
#   Cryo mix
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
temp2_test = temp2.copy()

# %%
info_to_test.shape, temp2_test.shape
# Out:
# ((71, 4), (56, 19))

# %%
temp2_test.drop(['Strain','Ferm condition','Cryo mix'], axis=1, inplace=True)

# %%
merge_test = pd.merge(temp2_test, info_to_test, on='FD sample ID')

# %%
merge_test.shape
# Out:
# (56, 19)

# %%
merge_test.head()
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
#
#   Bulking Desiccant             0            14            28  56  84  \
# 0     PVT   2%CaCl2  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1     PVT  10%CaCl2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2     PVT   10%SIO2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3     PVT   25%SIO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4     PVT     5%TMC  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper              Strain  \
# 0   11.095780   0.884324   -0.079040    0.050789  Kosakonia sacchari
# 1   11.119291   0.943177   -0.066643    0.034282  Kosakonia sacchari
# 2   11.078498   0.965821   -0.053539    0.021955  Kosakonia sacchari
# 3   11.089304   0.999838   -0.023865   -0.017218  Kosakonia sacchari
# 4   11.151777   0.746866   -0.173616    0.132266  Kosakonia sacchari
#
#   Ferm condition Cryo mix
# 0         T only   PVT70%
# 1         T only   PVT70%
# 2         T only   PVT70%
# 3         T only   PVT70%
# 4         T only   PVT70%

# %%
# Re-arrange the columns
merge_test = merge_test[['FD sample ID','FD Run ID','Strain','Cryo mix','Ferm condition',
                         'Storage form', 'Container', 'Temperature (°C)', 'Bulking', 'Desiccant',
                         '0','14','28','56','84','Decay Rate','R-squared','CI95_lower','CI95_upper']]

# %%
merge_test.head()
# Out:
#   FD sample ID           FD Run ID              Strain Cryo mix  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Kosakonia sacchari   PVT70%
# 1   23PT0119-5   FDL-105EF-T24-CC2  Kosakonia sacchari   PVT70%
# 2   23PT0119-5   FDL-105EF-T24-SO1  Kosakonia sacchari   PVT70%
# 3   23PT0119-5   FDL-105EF-T24-SO2  Kosakonia sacchari   PVT70%
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Kosakonia sacchari   PVT70%
#
#   Ferm condition   Storage form Container  Temperature (°C) Bulking Desiccant  \
# 0         T only  Bulked powder     Mylar                21     PVT   2%CaCl2
# 1         T only  Bulked powder     Mylar                21     PVT  10%CaCl2
# 2         T only  Bulked powder     Mylar                21     PVT   10%SIO2
# 3         T only  Bulked powder     Mylar                21     PVT   25%SIO2
# 4         T only  Bulked powder     Mylar                21     PVT     5%TMC
#
#               0            14            28  56  84  Decay Rate  R-squared  \
# 0  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN   11.095780   0.884324
# 1  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN   11.119291   0.943177
# 2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN   11.078498   0.965821
# 3  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN   11.089304   0.999838
# 4  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN   11.151777   0.746866
#
#    CI95_lower  CI95_upper
# 0   -0.079040    0.050789
# 1   -0.066643    0.034282
# 2   -0.053539    0.021955
# 3   -0.023865   -0.017218
# 4   -0.173616    0.132266

# %% [markdown]
# ## Joining all the dataframes function

# %% [markdown]
# **Info**

# %% [markdown]
# TO-DO in the web app
# 1. Select info = [['FD sample ID','Strain','Ferm condition','Cryo mix']]
# 2. Map the 'Ferm condition'
# 3. Drop duplicates to keep the unique 'FD sample ID'

# %%
full_info = pd.read_csv('sample_info.csv')
full_info.head()
# Out:
#   FD sample ID     FD Run ID                Strain    EFT date       Broth ID  \
# 0  22PT1202-10  FDL-105A-T01  Klebsiella variicola  2022-12-01   P080-22-Y048
# 1  22PT1202-12  FDL-105A-T02  Klebsiella variicola  2022-12-01   P080-22-Y048
# 2   22PT1202-5  FDL-105A-T03    Kosakonia sacchari  2022-12-01  P080-22-Y046
# 3  22PT1202-11  FDL-105A-T04  Klebsiella variicola  2022-12-01   P080-22-Y048
# 4   22PT1202-1  FDL-105B-T05    Kosakonia sacchari  2022-12-01  P080-22-Y046
#
#   Fermentation Scale                                     Ferm condition  \
# 0                14L  Potato peptone and tryptone, high viscosity by...
# 1                14L  Potato peptone and tryptone, high viscosity by...
# 2                14L  Potato peptone and tryptone, high viscosity by...
# 3                14L  Potato peptone and tryptone, high viscosity by...
# 4                14L         Potato peptone and tryptone, low viscosity
#
#    EFT (hr)  Broth titer (CFU/mL)  Broth age (day)  ... FD run time (hr)  \
# 0      48.0          3.540000e+11              1.0  ...             57.0
# 1      48.0          3.540000e+11              1.0  ...             57.0
# 2      48.0          1.180000e+11              1.0  ...             57.0
# 3      48.0          3.540000e+11              1.0  ...             57.0
# 4      48.0          1.180000e+11              1.0  ...             57.0
#
#   Primary ramp rate (C/min)      PA receive date  \
# 0                       NaN  2022-12-20 00:00:00
# 1                       NaN  2022-12-20 00:00:00
# 2                       NaN  2022-12-20 00:00:00
# 3                       NaN  2022-12-20 00:00:00
# 4                       NaN  2022-12-22 00:00:00
#
#                            Dried appearance   Container  Water activity  \
# 0                   fused/melted moist cake  Foil pouch            0.37
# 1                         Collapse, no dust  Foil pouch            0.06
# 2                       Collapse, some dust  Foil pouch            0.24
# 3                         Collapse, no dust  Foil pouch            0.05
# 4  friable cake, readily broke into pellets  Foil pouch            0.42
#
#   Viability (CFU/g) Cryo mix Coef Yield (%)  Log Loss
# 0               NaN         0.380       NaN       NaN
# 1      1.840000e+11         0.342     17.78     -0.75
# 2      6.610000e+10         0.285     15.96     -0.80
# 3      3.150000e+11         0.285     25.36     -0.60
# 4      4.070000e+10         0.380     13.11     -0.88
#
# [5 rows x 29 columns]

# %%
info_merge = full_info[['FD sample ID', 'Strain', 'Ferm condition', 'Cryo mix']]

# %%
for i in range(len(info_df['Ferm condition'])):
    if info_merge['Ferm condition'][i] in mapping_ferm_cond:
        info_merge['Ferm condition'][i] = mapping_ferm_cond[info_merge['Ferm condition'][i]]

# drop duplicates
info_merge = info_merge.drop_duplicates()

# %%
info_merge.shape
# Out:
# (71, 4)

# %%
info_merge.head()
# Out:
#   FD sample ID                Strain  \
# 0  22PT1202-10  Klebsiella variicola
# 1  22PT1202-12  Klebsiella variicola
# 2   22PT1202-5    Kosakonia sacchari
# 3  22PT1202-11  Klebsiella variicola
# 4   22PT1202-1    Kosakonia sacchari
#
#                                 Ferm condition Cryo mix
# 0                                 T+P, 0.7% XG      SKP
# 1                                 T+P, 0.7% XG      DSR
# 2                                 T+P, 0.7% XG   PVT70%
# 3                                 T+P, 0.7% XG   PVT70%
# 4   Potato peptone and tryptone, low viscosity      SKP

# %% [markdown]
# **User input**

# %%
real_input_df.head()
# Out:
#     FD sample ID           FD Run ID   Storage form Container  \
# 119   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar
# 120   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar
# 121   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar
# 122   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar
# 123   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar
#
#      Temperature (°C) Bulking Desiccant
# 119                21     PVT   2%CaCl2
# 120                21     PVT  10%CaCl2
# 121                21     PVT   10%SIO2
# 122                21     PVT   25%SIO2
# 123                21     PVT     5%TMC

# %% [markdown]
# **CFU**

# %%
decay_t3_final.head()
# Out:
#             FD Run ID             0            14            28  56  84  \
# 0   FDL-105EF-T24-CC1  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN
# 1   FDL-105EF-T24-CC2  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN
# 2   FDL-105EF-T24-SO1  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN
# 3   FDL-105EF-T24-SO2  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN
# 4  FDL-105EF-T24-TMC1  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN
#
#    Decay Rate  R-squared  CI95_lower  CI95_upper
# 0   11.095780   0.884324   -0.079040    0.050789
# 1   11.119291   0.943177   -0.066643    0.034282
# 2   11.078498   0.965821   -0.053539    0.021955
# 3   11.089304   0.999838   -0.023865   -0.017218
# 4   11.151777   0.746866   -0.173616    0.132266

# %%
decay_t2_final.head()
# Out:
#           FD Run ID         T0       Date  W0_CFU/mL  W1_CFU/mL     W8_CFU/mL  \
# 0  IFF09152022-2 T1 2023-01-05 2023-02-27        NaN        NaN  7.410000e+08
# 1  IFF09152022-2 T2 2023-01-05 2023-02-27        NaN        NaN  1.970000e+09
# 2  IFF09152022-2 T3 2023-01-05 2023-03-01        NaN        NaN  2.300000e+01
# 3  IFF09152022-2 T4 2023-01-05 2023-02-27        NaN        NaN  4.550000e+08
# 4  IFF09152022-3 T1 2023-01-05 2023-02-27        NaN        NaN  2.440000e+08
#
#    W0_CFU/g  W1_CFU/g      W8_CFU/g  W0_Water Activity  W1_Water Activity  \
# 0       NaN       NaN  1.410000e+10                NaN                NaN
# 1       NaN       NaN  3.750000e+10                NaN                NaN
# 2       NaN       NaN  4.500000e+00                NaN                NaN
# 3       NaN       NaN  8.640000e+09                NaN                NaN
# 4       NaN       NaN  4.640000e+09                NaN                NaN
#
#    W8_Water Activity Decay Rate R-squared CI95_lower CI95_upper
# 0              0.254       None      None       None       None
# 1              0.198       None      None       None       None
# 2                NaN       None      None       None       None
# 3              0.267       None      None       None       None
# 4              0.227       None      None       None       None

# %% [markdown]
# **Joining**

# %%
temp_a3 = pd.merge(left=real_input_df, right=decay_t3_final, on='FD Run ID', how='left')

# %%
temp_b3 = pd.merge(left=temp_a3, right=info_merge, on=['FD sample ID'], how='left')

# %%
temp_b3.shape
# Out:
# (56, 19)

# %%
temp_b3
# Out:
#    FD sample ID              FD Run ID   Storage form Container  \
# 0    23PT0119-5      FDL-105EF-T24-CC1  Bulked powder     Mylar
# 1    23PT0119-5      FDL-105EF-T24-CC2  Bulked powder     Mylar
# 2    23PT0119-5      FDL-105EF-T24-SO1  Bulked powder     Mylar
# 3    23PT0119-5      FDL-105EF-T24-SO2  Bulked powder     Mylar
# 4    23PT0119-5     FDL-105EF-T24-TMC1  Bulked powder     Mylar
# 5    23PT0119-5     FDL-105EF-T24-TMC2  Bulked powder     Mylar
# 6    22PT1117-8       FDL-105B-T10-CC1  Bulked powder     Mylar
# 7    22PT1117-8       FDL-105B-T10-CC2  Bulked powder     Mylar
# 8    23PT0119-8      FDL-105EF-T26-CC1  Bulked powder     Mylar
# 9    23PT0119-8      FDL-105EF-T26-CC2  Bulked powder     Mylar
# 10   23PT0119-8     FDL-105EF-T26-TMC1  Bulked powder     Mylar
# 11   23PT0119-8     FDL-105EF-T26-TMC2  Bulked powder     Mylar
# 12   23PT0119-8      FDL-105EF-T26-SO1  Bulked powder     Mylar
# 13   23PT0119-8      FDL-105EF-T26-SO2  Bulked powder     Mylar
# 14   23PT0119-2      FDL-105EF-T22-Try  Bulked powder     Mylar
# 15   23PT0119-5      FDL-105EF-T24-SKP  Bulked powder     Mylar
# 16   22PT1117-8       FDL-105B-T10-SKP  Bulked powder     Mylar
# 17   22PT1117-8       FDL-105B-T10-Try  Bulked powder     Mylar
# 18   22PT1117-5       FDL-105C-T15-SKP  Bulked powder     Mylar
# 19   22PT1117-5       FDL-105C-T15-Try  Bulked powder     Mylar
# 20   22PT1102-8       FDL-105C-T14-Try  Bulked powder     Mylar
# 21   22PT1102-7       FDL-105D-T20-Try  Bulked powder     Mylar
# 22   23PT0119-4       FDL-105G-T33-Try  Bulked powder     Mylar
# 23   23PT0227-4         FDL-111EF-T18   Bulked powder     Mylar
# 24   23PT0227-4  FDL-111EF-T18-CC1TMC1  Bulked powder     Mylar
# 25   23PT0227-4     FDL-111EF-T18-TMC1  Bulked powder     Mylar
# 26   23PT0227-6          FDL-111EF-T19  Bulked powder     Mylar
# 27   23PT0227-6  FDL-111EF-T19-CC1TMC1  Bulked powder     Mylar
# 28   23PT0227-6     FDL-111EF-T19-TMC1  Bulked powder     Mylar
# 29   23PT0227-4           FDL-111G-T22  Bulked powder     Mylar
# 30   23PT0227-4   FDL-111G-T22-CC1TMC1  Bulked powder     Mylar
# 31   23PT0227-4      FDL-111G-T22-TMC1  Bulked powder     Mylar
# 32   23PT0227-6          FDL-111G-T23   Bulked powder     Mylar
# 33   23PT0227-6   FDL-111G-T23-CC1TMC1  Bulked powder     Mylar
# 34   23PT0227-6      FDL-111G-T23-TMC1  Bulked powder     Mylar
# 35   23PT0227-4            FDL-111A-T2  Bulked powder     Mylar
# 36   23PT0227-4       FDL-111A-T2-TMC1  Bulked powder     Mylar
# 37   23PT0227-4       FDL-111A-T2-TMC2  Bulked powder     Mylar
# 38   23PT0227-6            FDL-111A-T3  Bulked powder     Mylar
# 39   23PT0227-6       FDL-111A-T3-TMC1  Bulked powder     Mylar
# 40   23PT0227-6       FDL-111A-T3-TMC2  Bulked powder     Mylar
# 41   23PT0227-8            FDL-111A-T4  Bulked powder     Mylar
# 42   23PT0227-8       FDL-111A-T4-TMC1  Bulked powder     Mylar
# 43   23PT0227-8       FDL-111A-T4-TMC2  Bulked powder     Mylar
# 44   23PT0227-8        FDL-111B-T8-CC1  Bulked powder     Mylar
# 45   23PT0227-8       FDL-111B-T8-TMC1  Bulked powder     Mylar
# 46   23PT0227-8            FDL-111B-T8  Bulked powder     Mylar
# 47   23PT0227-4       FDL-111D-T14-CC1  Bulked powder     Mylar
# 48   23PT0227-4      FDL-111D-T14-TMC1  Bulked powder     Mylar
# 49   23PT0227-4           FDL-111D-T14  Bulked powder     Mylar
# 50   23PT0227-6       FDL-111D-T15-CC1  Bulked powder     Mylar
# 51   23PT0227-6      FDL-111D-T15-TMC1  Bulked powder     Mylar
# 52   23PT0227-6           FDL-111D-T15  Bulked powder     Mylar
# 53   23PT0126-2           FDL-105K-T42  Bulked powder     Mylar
# 54   23PT0126-5           FDL-105K-T44  Bulked powder     Mylar
# 55   23PT0227-6      FDL-111G T23 TMC1  Bulked powder     Mylar
#
#     Temperature (°C)   Bulking      Desiccant             0            14  \
# 0                 21       PVT        2%CaCl2  1.133667e+11  9.563333e+10
# 1                 21       PVT       10%CaCl2  1.222333e+11  9.056667e+10
# 2                 21       PVT        10%SIO2  1.133667e+11  8.043333e+10
# 3                 21       PVT        25%SIO2  1.222333e+11  6.396667e+10
# 4                 21       PVT          5%TMC  1.133667e+11  1.140000e+11
# 5                 21       PVT         25%TMC  1.222333e+11  1.000667e+11
# 6                 21       PVT        2%CaCl2  1.260333e+11  1.026000e+11
# 7                 21       PVT       10%CaCl2  1.406000e+11  1.336333e+11
# 8                 21       PVT        2%CaCl2  1.169556e+11  8.993333e+10
# 9                 21       PVT       10%CaCl2  1.034444e+11  9.500000e+10
# 10                21       PVT         10%TMC  1.013333e+11  7.853333e+10
# 11                21       PVT         25%TMC  8.782222e+10  5.742222e+10
# 12                21       PVT        10%SIO2  7.177778e+10  5.362222e+10
# 13                21       PVT        25%SIO2  5.531111e+10  4.348889e+10
# 14                21  Tryptone         5%SIO2  9.204444e+10           NaN
# 15                21       SKP         5%SIO2  1.068222e+11           NaN
# 16                21       SKP         5%SIO2           NaN           NaN
# 17                21  Tryptone         5%SIO2           NaN           NaN
# 18                21       SKP         5%SIO2  6.502222e+10           NaN
# 19                21  Tryptone         5%SIO2  6.502222e+10           NaN
# 20                21  Tryptone         5%SIO2  1.000667e+11           NaN
# 21                21  Tryptone         5%SIO2  1.178000e+11           NaN
# 22                21  Tryptone         5%SIO2  5.151111e+10           NaN
# 23                21       PVT         5%SIO2  8.740000e+10           NaN
# 24                21       PVT  5%TMC+2%CaCl2  1.009111e+11           NaN
# 25                21       PVT          5%TMC  8.444444e+10           NaN
# 26                21       PVT         5%SIO2  1.089333e+11           NaN
# 27                21       PVT  5%TMC+2%CaCl2  1.427111e+11           NaN
# 28                21       PVT          5%TMC  1.072444e+11           NaN
# 29                21       PVT         5%SIO2  7.304444e+10           NaN
# 30                21       PVT  5%TMC+2%CaCl2  7.600000e+10           NaN
# 31                21       PVT          5%TMC  6.417778e+10           NaN
# 32                21       PVT         5%SIO2  7.388889e+10           NaN
# 33                21       PVT  5%TMC+2%CaCl2  7.811111e+10           NaN
# 34                21       PVT          5%TMC  7.895556e+10           NaN
# 35                21       PVT         5%SIO2  1.105800e+10  1.147600e+09
# 36                21       PVT          5%TMC  1.257800e+10  1.869600e+09
# 37                21       PVT         25%TMC  1.257800e+10  2.774000e+08
# 38                21       PVT         5%SIO2  1.953200e+10  2.698000e+09
# 39                21       PVT          5%TMC  1.960800e+10  3.458000e+09
# 40                21       PVT         25%TMC  1.960800e+10  4.218000e+09
# 41                21       PVT         5%SIO2  2.432000e+09  2.660000e+08
# 42                21       PVT          5%TMC  1.748000e+09  2.964000e+08
# 43                21       PVT         25%TMC  1.748000e+09  3.762000e+08
# 44                21       PVT        2%CaCl2  1.511556e+11  3.724000e+10
# 45                21       PVT          5%TMC  1.748000e+11  2.685333e+10
# 46                21       PVT         5%SIO2  1.389111e+11  1.798667e+10
# 47                21       PVT        2%CaCl2  1.292000e+11  1.216000e+10
# 48                21       PVT          5%TMC  1.266667e+11  9.880000e+09
# 49                21       PVT         5%SIO2  1.072444e+11  5.826667e+09
# 50                21       PVT        2%CaCl2  1.498889e+11  3.597333e+10
# 51                21       PVT          5%TMC  1.414444e+11  2.660000e+10
# 52                21       PVT         5%SIO2  1.574889e+11  2.204000e+10
# 53                21       PVT         5%SIO2  3.546667e+10           NaN
# 54                21       PVT         5%SIO2  6.840000e+10           NaN
# 55                21       PVT          5%TMC  7.895556e+10           NaN
#
#               28            56  84  Decay Rate  R-squared  CI95_lower  \
# 0   4.560000e+10           NaN NaN   11.095780   0.884324   -0.079040
# 1   4.306667e+10           NaN NaN   11.119291   0.943177   -0.066643
# 2   4.095556e+10           NaN NaN   11.078498   0.965821   -0.053539
# 3   3.251111e+10           NaN NaN   11.089304   0.999838   -0.023865
# 4   2.989333e+10           NaN NaN   11.151777   0.746866   -0.173616
# 5   4.028000e+10           NaN NaN   11.138573   0.880036   -0.097992
# 6   8.191111e+10           NaN NaN   11.101897   0.999318   -0.008902
# 7   9.162222e+10           NaN NaN   11.171626   0.837602   -0.043805
# 8   7.304444e+10           NaN NaN   11.064060   0.995515   -0.013528
# 9   7.557778e+10           NaN NaN   11.025098   0.934815   -0.021203
# 10  7.262222e+10           NaN NaN   10.992967   0.914318   -0.025266
# 11  3.926667e+10           NaN NaN   10.940360   0.998967   -0.017586
# 12  3.504444e+10           NaN NaN   10.865670   0.988535   -0.026337
# 13  2.575556e+10           NaN NaN   10.763325   0.956185   -0.044100
# 14  5.742222e+10           NaN NaN         NaN        NaN         NaN
# 15  3.800000e+10           NaN NaN         NaN        NaN         NaN
# 16  6.797778e+10  4.137778e+10 NaN         NaN        NaN         NaN
# 17  3.293333e+10  2.153333e+10 NaN         NaN        NaN         NaN
# 18  2.660000e+10  8.022222e+09 NaN   10.835130   0.992974   -0.033573
# 19  2.744444e+10  7.177778e+09 NaN   10.847705   0.984521   -0.044320
# 20  9.035556e+10  4.686667e+10 NaN   11.040415   0.848867   -0.037421
# 21  8.064444e+10  6.291111e+10 NaN   11.061691   0.985754   -0.012295
# 22  3.420000e+10  1.604444e+10 NaN   10.737039   0.971299   -0.028804
# 23           NaN           NaN NaN         NaN        NaN         NaN
# 24           NaN           NaN NaN         NaN        NaN         NaN
# 25           NaN           NaN NaN         NaN        NaN         NaN
# 26           NaN           NaN NaN         NaN        NaN         NaN
# 27           NaN           NaN NaN         NaN        NaN         NaN
# 28           NaN           NaN NaN         NaN        NaN         NaN
# 29           NaN           NaN NaN         NaN        NaN         NaN
# 30           NaN           NaN NaN         NaN        NaN         NaN
# 31           NaN           NaN NaN         NaN        NaN         NaN
# 32           NaN           NaN NaN         NaN        NaN         NaN
# 33           NaN           NaN NaN         NaN        NaN         NaN
# 34           NaN           NaN NaN         NaN        NaN         NaN
# 35           NaN           NaN NaN         NaN        NaN         NaN
# 36           NaN           NaN NaN         NaN        NaN         NaN
# 37           NaN           NaN NaN         NaN        NaN         NaN
# 38           NaN           NaN NaN         NaN        NaN         NaN
# 39           NaN           NaN NaN         NaN        NaN         NaN
# 40           NaN           NaN NaN         NaN        NaN         NaN
# 41           NaN           NaN NaN         NaN        NaN         NaN
# 42           NaN           NaN NaN         NaN        NaN         NaN
# 43           NaN           NaN NaN         NaN        NaN         NaN
# 44           NaN           NaN NaN         NaN        NaN         NaN
# 45           NaN           NaN NaN         NaN        NaN         NaN
# 46           NaN           NaN NaN         NaN        NaN         NaN
# 47           NaN           NaN NaN         NaN        NaN         NaN
# 48           NaN           NaN NaN         NaN        NaN         NaN
# 49           NaN           NaN NaN         NaN        NaN         NaN
# 50           NaN           NaN NaN         NaN        NaN         NaN
# 51           NaN           NaN NaN         NaN        NaN         NaN
# 52           NaN           NaN NaN         NaN        NaN         NaN
# 53  7.650667e+09           NaN NaN         NaN        NaN         NaN
# 54  2.153333e+09           NaN NaN         NaN        NaN         NaN
# 55           NaN           NaN NaN         NaN        NaN         NaN
#
#     CI95_upper                Strain  \
# 0     0.050789    Kosakonia sacchari
# 1     0.034282    Kosakonia sacchari
# 2     0.021955    Kosakonia sacchari
# 3    -0.017218    Kosakonia sacchari
# 4     0.132266    Kosakonia sacchari
# 5     0.063556    Kosakonia sacchari
# 6    -0.004465  Klebsiella variicola
# 7     0.030520  Klebsiella variicola
# 8    -0.001074  Klebsiella variicola
# 9     0.011466  Klebsiella variicola
# 10    0.014932  Klebsiella variicola
# 11   -0.007384  Klebsiella variicola
# 12    0.004097  Klebsiella variicola
# 13    0.020390  Klebsiella variicola
# 14         NaN    Kosakonia sacchari
# 15         NaN    Kosakonia sacchari
# 16         NaN  Klebsiella variicola
# 17         NaN  Klebsiella variicola
# 18    0.001117    Kosakonia sacchari
# 19    0.010138    Kosakonia sacchari
# 20    0.025656  Klebsiella variicola
# 21    0.002566  Klebsiella variicola
# 22    0.010712    Kosakonia sacchari
# 23         NaN    Kosakonia sacchari
# 24         NaN    Kosakonia sacchari
# 25         NaN    Kosakonia sacchari
# 26         NaN    Kosakonia sacchari
# 27         NaN    Kosakonia sacchari
# 28         NaN    Kosakonia sacchari
# 29         NaN    Kosakonia sacchari
# 30         NaN    Kosakonia sacchari
# 31         NaN    Kosakonia sacchari
# 32         NaN    Kosakonia sacchari
# 33         NaN    Kosakonia sacchari
# 34         NaN    Kosakonia sacchari
# 35         NaN    Kosakonia sacchari
# 36         NaN    Kosakonia sacchari
# 37         NaN    Kosakonia sacchari
# 38         NaN    Kosakonia sacchari
# 39         NaN    Kosakonia sacchari
# 40         NaN    Kosakonia sacchari
# 41         NaN    Kosakonia sacchari
# 42         NaN    Kosakonia sacchari
# 43         NaN    Kosakonia sacchari
# 44         NaN    Kosakonia sacchari
# 45         NaN    Kosakonia sacchari
# 46         NaN    Kosakonia sacchari
# 47         NaN    Kosakonia sacchari
# 48         NaN    Kosakonia sacchari
# 49         NaN    Kosakonia sacchari
# 50         NaN    Kosakonia sacchari
# 51         NaN    Kosakonia sacchari
# 52         NaN    Kosakonia sacchari
# 53         NaN    Kosakonia sacchari
# 54         NaN    Kosakonia sacchari
# 55         NaN    Kosakonia sacchari
#
#                                  Ferm condition Cryo mix
# 0                                        T only   PVT70%
# 1                                        T only   PVT70%
# 2                                        T only   PVT70%
# 3                                        T only   PVT70%
# 4                                        T only   PVT70%
# 5                                        T only   PVT70%
# 6    Potato peptone and tryptone, low viscosity   PVT70%
# 7    Potato peptone and tryptone, low viscosity   PVT70%
# 8                                           T+P   PVT70%
# 9                                           T+P   PVT70%
# 10                                          T+P   PVT70%
# 11                                          T+P   PVT70%
# 12                                          T+P   PVT70%
# 13                                          T+P   PVT70%
# 14                                          T+P   PVT70%
# 15                                       T only   PVT70%
# 16   Potato peptone and tryptone, low viscosity   PVT70%
# 17   Potato peptone and tryptone, low viscosity   PVT70%
# 18                                       P only   PVT70%
# 19                                       P only   PVT70%
# 20                              Glucose, no EPS   PVT70%
# 21                              Glucose, no EPS      SKP
# 22                                       T only      SKP
# 23                                       T only   PVT70%
# 24                                       T only   PVT70%
# 25                                       T only   PVT70%
# 26                                       P only   PVT70%
# 27                                       P only   PVT70%
# 28                                       P only   PVT70%
# 29                                       T only   PVT70%
# 30                                       T only   PVT70%
# 31                                       T only   PVT70%
# 32                                       P only   PVT70%
# 33                                       P only   PVT70%
# 34                                       P only   PVT70%
# 35                                       T only   PVT70%
# 36                                       T only   PVT70%
# 37                                       T only   PVT70%
# 38                                       P only   PVT70%
# 39                                       P only   PVT70%
# 40                                       P only   PVT70%
# 41                                  P only, con   PVT70%
# 42                                  P only, con   PVT70%
# 43                                  P only, con   PVT70%
# 44                                  P only, con   PVT70%
# 45                                  P only, con   PVT70%
# 46                                  P only, con   PVT70%
# 47                                       T only   PVT70%
# 48                                       T only   PVT70%
# 49                                       T only   PVT70%
# 50                                       P only   PVT70%
# 51                                       P only   PVT70%
# 52                                       P only   PVT70%
# 53                                          T+P   PVT70%
# 54                                 T+P, 0.7% XG   PVT70%
# 55                                       P only   PVT70%

# %%
temp_a2 = pd.merge(left=real_input_df, right=decay_t2_final.drop(['T0', 'Date'], axis=1), 
                  on='FD Run ID', how='left')

# %%
temp_b2 = pd.merge(left=temp_a2, right=info_merge, on=['FD sample ID'], how='left')

# %%
temp_b2.head()
# Out:
#   FD sample ID           FD Run ID   Storage form Container  Temperature (°C)  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Bulked powder     Mylar                21
# 1   23PT0119-5   FDL-105EF-T24-CC2  Bulked powder     Mylar                21
# 2   23PT0119-5   FDL-105EF-T24-SO1  Bulked powder     Mylar                21
# 3   23PT0119-5   FDL-105EF-T24-SO2  Bulked powder     Mylar                21
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Bulked powder     Mylar                21
#
#   Bulking Desiccant  W0_CFU/mL  W1_CFU/mL  W8_CFU/mL  ...  W0_Water Activity  \
# 0     PVT   2%CaCl2        NaN        NaN        NaN  ...                NaN
# 1     PVT  10%CaCl2        NaN        NaN        NaN  ...                NaN
# 2     PVT   10%SIO2        NaN        NaN        NaN  ...                NaN
# 3     PVT   25%SIO2        NaN        NaN        NaN  ...                NaN
# 4     PVT     5%TMC        NaN        NaN        NaN  ...                NaN
#
#    W1_Water Activity  W8_Water Activity  Decay Rate  R-squared  CI95_lower  \
# 0                NaN                NaN        None       None        None
# 1                NaN                NaN        None       None        None
# 2                NaN                NaN        None       None        None
# 3                NaN                NaN        None       None        None
# 4                NaN                NaN        None       None        None
#
#   CI95_upper              Strain Ferm condition Cryo mix
# 0       None  Kosakonia sacchari         T only   PVT70%
# 1       None  Kosakonia sacchari         T only   PVT70%
# 2       None  Kosakonia sacchari         T only   PVT70%
# 3       None  Kosakonia sacchari         T only   PVT70%
# 4       None  Kosakonia sacchari         T only   PVT70%
#
# [5 rows x 23 columns]

# %%
final_df = temp_b3[['FD sample ID','FD Run ID','Strain','Cryo mix','Ferm condition',
                         'Storage form', 'Container', 'Temperature (°C)', 'Bulking', 'Desiccant',
                         '0','14','28','56','84','Decay Rate','R-squared','CI95_lower','CI95_upper']]

# %%
final_df.head()
# Out:
#   FD sample ID           FD Run ID              Strain Cryo mix  \
# 0   23PT0119-5   FDL-105EF-T24-CC1  Kosakonia sacchari   PVT70%
# 1   23PT0119-5   FDL-105EF-T24-CC2  Kosakonia sacchari   PVT70%
# 2   23PT0119-5   FDL-105EF-T24-SO1  Kosakonia sacchari   PVT70%
# 3   23PT0119-5   FDL-105EF-T24-SO2  Kosakonia sacchari   PVT70%
# 4   23PT0119-5  FDL-105EF-T24-TMC1  Kosakonia sacchari   PVT70%
#
#   Ferm condition   Storage form Container  Temperature (°C) Bulking Desiccant  \
# 0         T only  Bulked powder     Mylar                21     PVT   2%CaCl2
# 1         T only  Bulked powder     Mylar                21     PVT  10%CaCl2
# 2         T only  Bulked powder     Mylar                21     PVT   10%SIO2
# 3         T only  Bulked powder     Mylar                21     PVT   25%SIO2
# 4         T only  Bulked powder     Mylar                21     PVT     5%TMC
#
#               0            14            28  56  84  Decay Rate  R-squared  \
# 0  1.133667e+11  9.563333e+10  4.560000e+10 NaN NaN   11.095780   0.884324
# 1  1.222333e+11  9.056667e+10  4.306667e+10 NaN NaN   11.119291   0.943177
# 2  1.133667e+11  8.043333e+10  4.095556e+10 NaN NaN   11.078498   0.965821
# 3  1.222333e+11  6.396667e+10  3.251111e+10 NaN NaN   11.089304   0.999838
# 4  1.133667e+11  1.140000e+11  2.989333e+10 NaN NaN   11.151777   0.746866
#
#    CI95_lower  CI95_upper
# 0   -0.079040    0.050789
# 1   -0.066643    0.034282
# 2   -0.053539    0.021955
# 3   -0.023865   -0.017218
# 4   -0.173616    0.132266

# %%
final_df.shape
# Out:
# (56, 19)

# %% [markdown]
# # Appendices

# %%
def pivot_on_seed(df):
    df = data_cleaning(df)
    raw_cfu = time_feature_eng(df) # long format

    pivot_rawcfu = df.pivot(index='FD Run ID', columns='Week', values=['CFU/mL', 'SD CFU/mL'])
    pivot_rawcfu.columns = [f"W{week}_{scale}" for scale, week in pivot_rawcfu.columns.to_list()]
    
    # select features from input file
    cfu = df.drop(['Sample Description', 'CFU/mL', 'SD CFU/mL', 'CV (%)', 'Day', 'Week'], axis=1)
    cfu = cfu.drop_duplicates(subset='FD Run ID').reset_index(drop=True)

    # join the pivot df with the original info
    clean_cfu = pd.merge(cfu, pivot_rawcfu, on='FD Run ID') # wide format

    return raw_cfu, clean_cfu

# %% [markdown]
# ### Tranpose columns to rows

# %%
# create a sample dataframe
data = {'Name': ['John', 'Mary', 'Peter'],
        'Age': [25, 30, 35],
        'Salary_2019': [50000, 60000, 70000],
        'Salary_2020': [55000, 65000, 75000],
        'Salary_2021': [60000, 70000, 80000]}

df = pd.DataFrame(data)

# melt the data to transpose columns to rows
melted_df = pd.melt(df, id_vars=['Name', 'Age'], var_name='Year', value_name='Salary')

# print the transposed dataframe
print(melted_df)
# Out:
#     Name  Age         Year  Salary
# 0   John   25  Salary_2019   50000
# 1   Mary   30  Salary_2019   60000
# 2  Peter   35  Salary_2019   70000
# 3   John   25  Salary_2020   55000
# 4   Mary   30  Salary_2020   65000
# 5  Peter   35  Salary_2020   75000
# 6   John   25  Salary_2021   60000
# 7   Mary   30  Salary_2021   70000
# 8  Peter   35  Salary_2021   80000

# %%
df
# Out:
#     Name  Age  Salary_2019  Salary_2020  Salary_2021
# 0   John   25        50000        55000        60000
# 1   Mary   30        60000        65000        70000
# 2  Peter   35        70000        75000        80000

# %% [markdown]
# ### Tranpose rows to columns

# %%
# create a sample dataframe
data = {'Name': ['John', 'Mary', 'Peter'],
        'Year': [2019, 2020, 2021],
        'Salary': [50000, 60000, 70000]}

df1 = pd.DataFrame(data)

# pivot the data to transpose rows to columns
pivoted_df = df1.pivot(index='Name', columns='Year', values='Salary')

# print the transposed dataframe
print(pivoted_df)
# Out:
# Year      2019     2020     2021
# Name
# John   50000.0      NaN      NaN
# Mary       NaN  60000.0      NaN
# Peter      NaN      NaN  70000.0

# %%
df1
# Out:
#     Name  Year  Salary
# 0   John  2019   50000
# 1   Mary  2020   60000
# 2  Peter  2021   70000

# %% [markdown]
# ### Pivot

# %%
import pandas as pd

# Create a sample DataFrame and pivot table
df = pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'c']}, index=['X', 'Y', 'Z'])
pivot_table = pd.pivot_table(df, values='A', index='B', aggfunc='sum')

# Join the pivot table with the original DataFrame
joined_df = df.join(pivot_table, on='B', rsuffix='_sum')

# Display the joined DataFrame
print(joined_df)
# Out:
#    A  B  A_sum
# X  1  a      1
# Y  2  b      2
# Z  3  c      3

# %%
df
# Out:
#    A  B
# X  1  a
# Y  2  b
# Z  3  c

# %%
pivot_table
# Out:
#    A
# B
# a  1
# b  2
# c  3

# %%
import pandas as pd

# create a pivot table
df_pivot = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
                         'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
                         'C': [1, 2, 3, 4, 5, 6, 7, 8],
                         'D': [10, 20, 30, 40, 50, 60, 70, 80]}).pivot_table(index='A', columns='B', values='C')

# create a regular DataFrame
df_normal = pd.DataFrame({'A': ['foo', 'bar', 'baz'], 'E': [100, 200, 300]})

# reset the index of the pivot DataFrame
df_pivot = df_pivot.reset_index()

# join the two DataFrames on the 'A' column
df_merged = pd.merge(df_pivot, df_normal, on='A')

print(df_merged)
# Out:
#      A  one  two    E
# 0  bar    5    6  200
# 1  foo    3    4  100

# %%
df_pivot
# Out:
# B    A  one  two
# 0  bar    5    6
# 1  foo    3    4

# %%
df_normal
# Out:
#      A    E
# 0  foo  100
# 1  bar  200
# 2  baz  300

# %% [markdown]
# ### statsmodel library

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
a
# Out:
#             FD Run ID Day         CFU/g     LogCFU
# 6    FDL-105B-T10-CC1   0  1.260333e+11  11.100485
# 73   FDL-105B-T10-CC1  14  1.026000e+11  11.011147
# 140  FDL-105B-T10-CC1  28  8.191111e+10  10.913343

# %%
a['Day'] = a['Day'].astype('float64')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 6 to 140
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FD Run ID  3 non-null      object
#  1   Day        3 non-null      float64
#  2   CFU/g      3 non-null      float64
#  3   LogCFU     3 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 120.0+ bytes

# %%
X = a['Day']
y = a['LogCFU']

# %%
# Assuming you have a DataFrame called 'df' with columns 'X' and 'Y'
df = pd.DataFrame({'X': [1, 2, 3, 4, 5], 'Y': [2, 4, 5, 4, 5]})

# Extract the input features and target variable
X = df['X']
y = df['Y']

# Add a constant term to the input features
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Calculate the predicted values
predictions = results.predict(X)

# Calculate the 95% confidence interval
ci = results.conf_int(alpha=0.05)

# Calculate the error bars
error_bars = ci.diff(axis=1) / 2

# Print the confidence interval and error bars
print("95% Confidence Interval:")
print(ci)
print()
print("Error Bars:")
print(error_bars)

# %% [markdown]
# Calculate Confidence Interval: https://stackoverflow.com/questions/61292464/get-confidence-interval-from-sklearn-linear-regression-in-python

# %% [markdown]
# ### Use breakpoint
#
# Command:
# - l: current position
# - n: next line
# - c: continue
# - exit: exit the breakpoint()

# %%
def decay_rate_statsmodel(df):
    
    # prepare the variables
    #df.rename(columns={'Time point (day)':'Day'}, inplace=True)
    #df['LogCFU'] = np.log10(df['CFU/g'])
    
    # Extract the input feature and target variable
    X = df['Day'].astype('float64') #require to be float/int
    y = df['LogCFU']
    
    # Add a constant term to the input feature
    X = sm.add_constant(X)
    
    # Fit the linear regression model
    model = sm.OLS(y, X)
    results = model.fit()
    
    # Extract the coefficient and R-squared
    decay_rate = results.params[1]
    r_squared = results.rsquared
    breakpoint()
    
    # Extract the 95% confidence interval
    ci = results.conf_int(alpha=0.05)
    ci_slope = ci.loc['Day']

    decay_df = pd.Series({'Decay Rate': decay_rate, 'R-squared': r_squared})
    decay_df = pd.concat([decay_df, ci_slope])
    decay_df.rename(index={0:'decay_rate_95ci_lower', 1:'decay_rate_95ci_upper'}, inplace=True)
    
    return decay_df

# %%
# test 1
t1 = a.copy()

# %%
t1
# Out:
#             FD Run ID   Day         CFU/g     LogCFU
# 6    FDL-105B-T10-CC1   0.0  1.260333e+11  11.100485
# 73   FDL-105B-T10-CC1  14.0  1.026000e+11  11.011147
# 140  FDL-105B-T10-CC1  28.0  8.191111e+10  10.913343

# %%
decay_rate_statsmodel(t1)
# Out:
# > <ipython-input-107-9e6c41a64d89>(24)decay_rate_statsmodel()
# -> ci = results.conf_int(alpha=0.05)
# (Pdb) l
#  19  	    decay_rate = results.params[1]
#  20  	    r_squared = results.rsquared
#  21  	    breakpoint()
#  22
#  23  	    # Extract the 95% confidence interval
#  24  ->	    ci = results.conf_int(alpha=0.05)
#  25  	    ci_slope = ci.loc['Day']
#  26
#  27  	    decay_df = pd.Series({'Decay Rate': decay_rate, 'R-squared': r_squared})
#  28  	    decay_df = pd.concat([decay_df, ci_slope])
#  29  	    decay_df.rename(index={0:'decay_rate_95ci_lower', 1:'decay_rate_95ci_upper'}, inplace=True)
# (Pdb) decay_rates
# *** NameError: name 'decay_rates' is not defined
# (Pdb) decay_rate
# -0.006683664483398799
# (Pdb) exit()
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-112-9ba6f55466e1> in <module>
# ----> 1 decay_rate_statsmodel(t1)
#
# <ipython-input-107-9e6c41a64d89> in decay_rate_statsmodel(df)
#      22
#      23     # Extract the 95% confidence interval
# ---> 24     ci = results.conf_int(alpha=0.05)
#      25     ci_slope = ci.loc['Day']
#      26
#
# <ipython-input-107-9e6c41a64d89> in decay_rate_statsmodel(df)
#      22
#      23     # Extract the 95% confidence interval
# ---> 24     ci = results.conf_int(alpha=0.05)
#      25     ci_slope = ci.loc['Day']
#      26
#
# /opt/anaconda3/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /opt/anaconda3/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# ### Merge dataframes
# 1. Merge dataframes
# 2. Fill missing information from the sample roots' names
# 3. 'Info' belongs to parent, I can fill in the NaN for granchildren without concerning about the children

# %%
df1 = pd.DataFrame({'Sample': ['A', 'A', 'B', 'B'], 'ID': ['A1', 'A2', 'B1', 'B3'],
                   'Info': ['foo','bar','one','two']})


df2 = pd.DataFrame({'Sample': ['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B','B'], 
                    'ID': ['A1', 'A1_a', 'A1_b', 'A2', 'A2_c', 'B1_a', 'B1_b', 'B3', 'B3_a','B3_b'],
                   'Cond':['bag','bag','zip','bag','zip','bag','bag','zip','zip','bag']})

# %%
# resemble sample_info df
df1
# Out:
#   Sample  ID Info
# 0      A  A1  foo
# 1      A  A2  bar
# 2      B  B1  one
# 3      B  B3  two

# %%
# resemble real_input_df
df2
# Out:
#   Sample    ID Cond
# 0      A    A1  bag
# 1      A  A1_a  bag
# 2      A  A1_b  zip
# 3      A    A2  bag
# 4      A  A2_c  zip
# 5      B  B1_a  bag
# 6      B  B1_b  bag
# 7      B    B3  zip
# 8      B  B3_a  zip
# 9      B  B3_b  bag

# %%
merged_df = df1.merge(df2, on=['Sample', 'ID'], how='right')

# %%
merged_df
# Out:
#   Sample    ID Info Cond
# 0      A    A1  foo  bag
# 1      A  A1_a  NaN  bag
# 2      A  A1_b  NaN  zip
# 3      A    A2  bar  bag
# 4      A  A2_c  NaN  zip
# 5      B  B1_a  NaN  bag
# 6      B  B1_b  NaN  bag
# 7      B    B3  two  zip
# 8      B  B3_a  NaN  zip
# 9      B  B3_b  NaN  bag

# %% [markdown]
# A1, A1_a, A1_b shared the same roots "A1" and A.
# - carry the "info" downward throughout 'A' entries
# - sort the values of ID to make sure it's in order to fill upward or downward
#
# **case study**
# - Sample: parent
# - ID: children + grandchildren
#
# There is a case where the children don't show up, but the grandchildren do.
# I still need the info from the parent to pass down to the grandchildren.
#
# *Example:* At index 5-6, B - B1 - B1_a and B - B1 - B1_b
# - the children B1 doesn't show in df2
# - but need to establish the **'info' from B to B1_a and B1_b**

# %%
filled_df = merged_df.copy()

# %%
# B3_a shouldn't be filled
filled_df.fillna(method='ffill')
# Out:
#   Sample    ID Info Cond
# 0      A    A1  foo  bag
# 1      A  A1_a  foo  bag
# 2      A  A1_b  foo  zip
# 3      A    A2  bar  bag
# 4      A  A2_c  bar  zip
# 5      B    B1  one  zip
# 6      B  B1_a  one  bag
# 7      B  B1_b  one  bag
# 8      B  B3_a  one  zip

# %%
import pandas as pd

df1 = pd.DataFrame({'Sample': ['A', 'A', 'B', 'B'], 'ID': ['A1', 'A2', 'B1', 'B3']})
df2 = pd.DataFrame({'Sample': ['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'], 'ID': ['A1', 'A1_a', 'A1_b', 'A2', 'A2_c', 'B1', 'B1_a', 'B1_b', 'B3_a']})

merged_df_a = df1.merge(df2, on=['Sample','ID'], how='right')

# %%
# I want only 9 entries like this
merged_df_a
# Out:
#   Sample    ID
# 0      A    A1
# 1      A  A1_a
# 2      A  A1_b
# 3      A    A2
# 4      A  A2_c
# 5      B    B1
# 6      B  B1_a
# 7      B  B1_b
# 8      B  B3_a

# %%
merged_df_b = df2.merge(df1, on='ID', how='left')

# %%
merged_df_b
# Out:
#   Sample_x    ID Sample_y
# 0        A    A1        A
# 1        A  A1_a      NaN
# 2        A  A1_b      NaN
# 3        A    A2        A
# 4        A  A2_c      NaN
# 5        B    B1        B
# 6        B  B1_a      NaN
# 7        B  B1_b      NaN
# 8        B  B3_a      NaN

# %% [markdown]
# ### Use fuzz calculate the similarity

# %%
cfu_df.loc[cfu_df['FD Run ID'].str.contains("FDL-111A-T2")]['FD Run ID'].str.split("-")
# Out:
# 36            [FDL, 111A, T2]
# 41    [FDL, 111A, T2 5% SiO2]
# 44       [FDL, 111A, T2 TMC1]
# Name: FD Run ID, dtype: object

# %%
a = "FDL-111A-T2-TMC1"
b = "FDL-111A T2 TMC1"
c = "FDL-111A-T2"
d = "FDL-111A T2 TMC2"

# %%
from thefuzz import fuzz

# %%
fuzz.ratio(b, d)
# Out:
# 94

# %%
fuzz.ratio(a, c)
# Out:
# 81

# %%
fuzz.ratio(b, c)
# Out:
# 74

# %%
fuzz.ratio(b, a)
# Out:
# 88
